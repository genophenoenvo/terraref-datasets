# %% [markdown]
# ## Query betydb for phenotypes dataset
# * Season 4 & Season 6
# * Wide format: one row per plot
# * Days to Emergence
# * Days to Flowering
# * Aboveground dry biomass

# %%
import pandas as pd
import numpy as np

from platform import python_version

# print(python_version())
# Out:
# 3.7.4

# %%
# %pwd
# %cd '/Users/ejcain/Dev/UA-AG/phenotypes/terraref-datasets/'
# Out:
# /Users/ejcain/Dev/UA-AG/phenotypes/terraref-datasets

# %%
# MAC Season 4 

mac_season_4_df = pd.read_csv('mac_season_4.csv')
mac_season_4_df.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (18,32,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  checked result_type          id   citation_id     site_id  \
# 0           1        0      traits  6001970065  6.000000e+09  6000008410
# 1           2        0      traits  6001970066  6.000000e+09  6000008410
# 2           3        0      traits  6001970097  6.000000e+09  6000007597
# 3           4        0      traits  6001970098  6.000000e+09  6000007597
# 4           5        0      traits  6001970099  6.000000e+09  6000007597
#
#    treatment_id                                         sitename      city  \
# 0  6.000000e+09  MAC Field Scanner Season 4 Range 46 Column 14 E  Maricopa
# 1  6.000000e+09  MAC Field Scanner Season 4 Range 46 Column 14 E  Maricopa
# 2  6.000000e+09   MAC Field Scanner Season 4 Range 21 Column 8 W  Maricopa
# 3  6.000000e+09   MAC Field Scanner Season 4 Range 21 Column 8 W  Maricopa
# 4  6.000000e+09   MAC Field Scanner Season 4 Range 21 Column 8 W  Maricopa
#
#          lat  ...   n statname stat notes  access_level  cultivar entity  \
# 0  33.076165  ... NaN      NaN  NaN   NaN             2  PI564163    NaN
# 1  33.076165  ... NaN      NaN  NaN   NaN             2  PI564163    NaN
# 2  33.075266  ... NaN      NaN  NaN   NaN             2  PI505722    NaN
# 3  33.075266  ... NaN      NaN  NaN   NaN             2  PI505722    NaN
# 4  33.075266  ... NaN      NaN  NaN   NaN             2  PI505722    NaN
#
#                                          method_name  \
# 0  temperature of sunlit leaf with [instrument name]
# 1  temperature of sunlit leaf with [instrument name]
# 2  temperature of sunlit leaf with [instrument name]
# 3  temperature of sunlit leaf with [instrument name]
# 4  temperature of sunlit leaf with [instrument name]
#
#                                             view_url  \
# 0  https://terraref.ncsa.illinois.edu/bety/traits...
# 1  https://terraref.ncsa.illinois.edu/bety/traits...
# 2  https://terraref.ncsa.illinois.edu/bety/traits...
# 3  https://terraref.ncsa.illinois.edu/bety/traits...
# 4  https://terraref.ncsa.illinois.edu/bety/traits...
#
#                                             edit_url
# 0  https://terraref.ncsa.illinois.edu/bety/traits...
# 1  https://terraref.ncsa.illinois.edu/bety/traits...
# 2  https://terraref.ncsa.illinois.edu/bety/traits...
# 3  https://terraref.ncsa.illinois.edu/bety/traits...
# 4  https://terraref.ncsa.illinois.edu/bety/traits...
#
# [5 rows x 39 columns]

# %%
# try specifying dtype to eliminate DtypeWarning

df2 = pd.read_csv('mac_season_4.csv', sep=',', dtype={'a': str})
df2.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (18,32,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  checked result_type          id   citation_id     site_id  \
# 0           1        0      traits  6001970065  6.000000e+09  6000008410
# 1           2        0      traits  6001970066  6.000000e+09  6000008410
# 2           3        0      traits  6001970097  6.000000e+09  6000007597
# 3           4        0      traits  6001970098  6.000000e+09  6000007597
# 4           5        0      traits  6001970099  6.000000e+09  6000007597
#
#    treatment_id                                         sitename      city  \
# 0  6.000000e+09  MAC Field Scanner Season 4 Range 46 Column 14 E  Maricopa
# 1  6.000000e+09  MAC Field Scanner Season 4 Range 46 Column 14 E  Maricopa
# 2  6.000000e+09   MAC Field Scanner Season 4 Range 21 Column 8 W  Maricopa
# 3  6.000000e+09   MAC Field Scanner Season 4 Range 21 Column 8 W  Maricopa
# 4  6.000000e+09   MAC Field Scanner Season 4 Range 21 Column 8 W  Maricopa
#
#          lat  ...   n statname stat notes  access_level  cultivar entity  \
# 0  33.076165  ... NaN      NaN  NaN   NaN             2  PI564163    NaN
# 1  33.076165  ... NaN      NaN  NaN   NaN             2  PI564163    NaN
# 2  33.075266  ... NaN      NaN  NaN   NaN             2  PI505722    NaN
# 3  33.075266  ... NaN      NaN  NaN   NaN             2  PI505722    NaN
# 4  33.075266  ... NaN      NaN  NaN   NaN             2  PI505722    NaN
#
#                                          method_name  \
# 0  temperature of sunlit leaf with [instrument name]
# 1  temperature of sunlit leaf with [instrument name]
# 2  temperature of sunlit leaf with [instrument name]
# 3  temperature of sunlit leaf with [instrument name]
# 4  temperature of sunlit leaf with [instrument name]
#
#                                             view_url  \
# 0  https://terraref.ncsa.illinois.edu/bety/traits...
# 1  https://terraref.ncsa.illinois.edu/bety/traits...
# 2  https://terraref.ncsa.illinois.edu/bety/traits...
# 3  https://terraref.ncsa.illinois.edu/bety/traits...
# 4  https://terraref.ncsa.illinois.edu/bety/traits...
#
#                                             edit_url
# 0  https://terraref.ncsa.illinois.edu/bety/traits...
# 1  https://terraref.ncsa.illinois.edu/bety/traits...
# 2  https://terraref.ncsa.illinois.edu/bety/traits...
# 3  https://terraref.ncsa.illinois.edu/bety/traits...
# 4  https://terraref.ncsa.illinois.edu/bety/traits...
#
# [5 rows x 39 columns]

# %%
# confirm same shape from R

df2.shape
# Out:
# (372363, 39)

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'checked', 'result_type', 'id', 'citation_id', 'site_id',
#        'treatment_id', 'sitename', 'city', 'lat', 'lon', 'scientificname',
#        'commonname', 'genus', 'species_id', 'cultivar_id', 'author',
#        'citation_year', 'treatment', 'date', 'time', 'raw_date', 'month',
#        'year', 'dateloc', 'trait', 'trait_description', 'mean', 'units', 'n',
#        'statname', 'stat', 'notes', 'access_level', 'cultivar', 'entity',
#        'method_name', 'view_url', 'edit_url'],
#       dtype='object')

# %%
# mixed dtypes in columns 18, 32, 35

print(df2.columns[18], df2.columns[32], df2.columns[35])
# Out:
# treatment notes entity

# %%
df2['treatment'].head()
# Out:
# 0    BAP 2017, water-deficit stress Aug 1-14
# 1    BAP 2017, water-deficit stress Aug 1-14
# 2    BAP 2017, water-deficit stress Aug 1-14
# 3    BAP 2017, water-deficit stress Aug 1-14
# 4    BAP 2017, water-deficit stress Aug 1-14
# Name: treatment, dtype: object

# %%
df2['notes'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: notes, dtype: object

# %%
df2['entity'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: entity, dtype: object

# %%
df2.result_type.unique()
# Out:
# array(['traits'], dtype=object)

# %%
df2.iloc[5]
# Out:
# Unnamed: 0                                                           6
# checked                                                              0
# result_type                                                     traits
# id                                                          6001970112
# citation_id                                                      6e+09
# site_id                                                     6000008410
# treatment_id                                                     6e+09
# sitename               MAC Field Scanner Season 4 Range 46 Column 14 E
# city                                                          Maricopa
# lat                                                            33.0762
# lon                                                           -111.975
# scientificname                                         Sorghum bicolor
# commonname                                                     sorghum
# genus                                                          Sorghum
# species_id                                                        2588
# cultivar_id                                                 6000000231
# author                                                  Newcomb, Maria
# citation_year                                                     2017
# treatment                      BAP 2017, water-deficit stress Aug 1-14
# date                                                       2017 Jun 26
# time                                        12:45:00 (America/Phoenix)
# raw_date                                     2017-06-26 14:45:00 -0500
# month                                                                6
# year                                                              2017
# dateloc                                                              5
# trait                                                 leaf_temperature
# trait_description          temperature of the surface of a sunlit leaf
# mean                                                            307.65
# units                                                                K
# n                                                                  NaN
# statname                                                           NaN
# stat                                                               NaN
# notes                                                              NaN
# access_level                                                         2
# cultivar                                                      PI564163
# entity                                                             NaN
# method_name          temperature of sunlit leaf with [instrument name]
# view_url             https://terraref.ncsa.illinois.edu/bety/traits...
# edit_url             https://terraref.ncsa.illinois.edu/bety/traits...
# Name: 5, dtype: object

# %%
df2.trait.unique()
# Out:
# array(['leaf_temperature', 'planter_seed_drop', 'aboveground_dry_biomass',
#        'seedling_emergence_rate', 'panicle_height', 'stand_count',
#        'dry_matter_fraction', 'harvest_lodging_rating', 'flowering_time',
#        'stalk_diameter_fixed_height', 'stalk_diameter_minor_axis',
#        'stalk_diameter_major_axis', 'grain_stage_time',
#        'stem_elongated_internodes_number', 'leaf_width', 'canopy_cover',
#        'lodging_present', 'surface_temperature', 'emergence_count',
#        'flag_leaf_emergence_time', 'leaf_stomatal_conductance',
#        'absorbance_650', 'absorbance_850', 'roll', 'PhiNO', 'PhiNPQ',
#        'absorbance_530', 'absorbance_605', 'absorbance_730',
#        'absorbance_880', 'absorbance_940', 'Fs', 'NPQt', 'qL', 'qP',
#        'RFd', 'SPAD_530', 'SPAD_605', 'SPAD_730', 'leaf_thickness',
#        'ambient_humidity', 'leaf_angle_clamp_position', 'pitch',
#        'proximal_air_temperature', 'FvP/FmP', 'gH+', 'ECSt',
#        'leaf_temperature_differential', 'Phi2', 'relative_chlorophyll',
#        'FmPrime', 'FoPrime', 'LEF', 'SPAD_420', 'SPAD_650', 'SPAD_850',
#        'SPAD_880', 'light_intensity_PAR', 'vH+', 'leaf_angle_mean',
#        'leaf_angle_alpha', 'leaf_angle_beta', 'leaf_angle_chi',
#        'canopy_height', 'anthocyanin_index', 'leaf_length',
#        'aboveground_biomass_moisture', 'panicle_count', 'panicle_volume',
#        'panicle_surface_area', 'leaf_desiccation_present',
#        'chlorophyll_index', 'flavonol_index',
#        'NBI_nitrogen_balance_index', 'plant_basal_tiller_number',
#        'absorbance_420', 'aboveground_fresh_biomass'], dtype=object)

# %%
df2.sitename.nunique()
# Out:
# 2221

# %%
df2.site_id.nunique()
# Out:
# 2221

# %%
df2.sitename.unique()
# Out:
# array(['MAC Field Scanner Season 4 Range 46 Column 14 E',
#        'MAC Field Scanner Season 4 Range 21 Column 8 W',
#        'MAC Field Scanner Season 4 Range 13 Column 14', ...,
#        'MAC Field Scanner Season 4 Range 30 Column 3 W',
#        'MAC Field Scanner Season 4 Range 20 Column 13 W',
#        'MAC Field Scanner Season 4 Range 20 Column 12 E'], dtype=object)

# %%
df2.sitename.head(25)
# Out:
# 0     MAC Field Scanner Season 4 Range 46 Column 14 E
# 1     MAC Field Scanner Season 4 Range 46 Column 14 E
# 2      MAC Field Scanner Season 4 Range 21 Column 8 W
# 3      MAC Field Scanner Season 4 Range 21 Column 8 W
# 4      MAC Field Scanner Season 4 Range 21 Column 8 W
# 5     MAC Field Scanner Season 4 Range 46 Column 14 E
# 6     MAC Field Scanner Season 4 Range 46 Column 14 E
# 7     MAC Field Scanner Season 4 Range 46 Column 14 E
# 8     MAC Field Scanner Season 4 Range 46 Column 14 E
# 9     MAC Field Scanner Season 4 Range 46 Column 14 E
# 10    MAC Field Scanner Season 4 Range 46 Column 14 E
# 11    MAC Field Scanner Season 4 Range 46 Column 14 E
# 12    MAC Field Scanner Season 4 Range 46 Column 14 E
# 13    MAC Field Scanner Season 4 Range 46 Column 14 E
# 14    MAC Field Scanner Season 4 Range 46 Column 14 E
# 15    MAC Field Scanner Season 4 Range 46 Column 14 E
# 16    MAC Field Scanner Season 4 Range 46 Column 14 E
# 17    MAC Field Scanner Season 4 Range 46 Column 14 E
# 18    MAC Field Scanner Season 4 Range 46 Column 14 E
# 19    MAC Field Scanner Season 4 Range 46 Column 14 E
# 20    MAC Field Scanner Season 4 Range 46 Column 14 E
# 21    MAC Field Scanner Season 4 Range 46 Column 14 E
# 22    MAC Field Scanner Season 4 Range 46 Column 14 E
# 23      MAC Field Scanner Season 4 Range 13 Column 14
# 24      MAC Field Scanner Season 4 Range 13 Column 14
# Name: sitename, dtype: object

# %%
df2.loc[df2.trait == 'aboveground_dry_biomass'].head()
# Out:
#      Unnamed: 0  checked result_type          id   citation_id     site_id  \
# 864         865        0      traits  6001965127  6.000000e+09  6000005241
# 865         866        0      traits  6001965147  6.000000e+09  6000005237
# 866         867        0      traits  6001965192  6.000000e+09  6000005345
# 867         868        0      traits  6001965202  6.000000e+09  6000005351
# 868         869        0      traits  6001965232  6.000000e+09  6000005369
#
#      treatment_id                                      sitename      city  \
# 864  6.000000e+09   MAC Field Scanner Season 4 Range 2 Column 5  Maricopa
# 865  6.000000e+09   MAC Field Scanner Season 4 Range 2 Column 9  Maricopa
# 866  6.000000e+09   MAC Field Scanner Season 4 Range 3 Column 4  Maricopa
# 867  6.000000e+09   MAC Field Scanner Season 4 Range 3 Column 6  Maricopa
# 868  6.000000e+09  MAC Field Scanner Season 4 Range 3 Column 12  Maricopa
#
#            lat  ...   n statname stat notes  access_level  cultivar entity  \
# 864  33.074584  ... NaN      NaN  NaN   NaN             2    SP1615    NaN
# 865  33.074584  ... NaN      NaN  NaN   NaN             2    SP1615    NaN
# 866  33.074619  ... NaN      NaN  NaN   NaN             2  PI145626    NaN
# 867  33.074620  ... NaN      NaN  NaN   NaN             2  PI330181    NaN
# 868  33.074620  ... NaN      NaN  NaN   NaN             2  PI152771    NaN
#
#                                method_name  \
# 864  Whole above ground biomass at harvest
# 865  Whole above ground biomass at harvest
# 866  Whole above ground biomass at harvest
# 867  Whole above ground biomass at harvest
# 868  Whole above ground biomass at harvest
#
#                                               view_url  \
# 864  https://terraref.ncsa.illinois.edu/bety/traits...
# 865  https://terraref.ncsa.illinois.edu/bety/traits...
# 866  https://terraref.ncsa.illinois.edu/bety/traits...
# 867  https://terraref.ncsa.illinois.edu/bety/traits...
# 868  https://terraref.ncsa.illinois.edu/bety/traits...
#
#                                               edit_url
# 864  https://terraref.ncsa.illinois.edu/bety/traits...
# 865  https://terraref.ncsa.illinois.edu/bety/traits...
# 866  https://terraref.ncsa.illinois.edu/bety/traits...
# 867  https://terraref.ncsa.illinois.edu/bety/traits...
# 868  https://terraref.ncsa.illinois.edu/bety/traits...
#
# [5 rows x 39 columns]

# %%
df2.iloc[864]
# Out:
# Unnamed: 0                                                         865
# checked                                                              0
# result_type                                                     traits
# id                                                          6001965127
# citation_id                                                      6e+09
# site_id                                                     6000005241
# treatment_id                                                     6e+09
# sitename                   MAC Field Scanner Season 4 Range 2 Column 5
# city                                                          Maricopa
# lat                                                            33.0746
# lon                                                           -111.975
# scientificname                                         Sorghum bicolor
# commonname                                                     sorghum
# genus                                                          Sorghum
# species_id                                                        2588
# cultivar_id                                                 6000001054
# author                                                  Newcomb, Maria
# citation_year                                                     2017
# treatment                      BAP 2017, water-deficit stress Aug 1-14
# date                                     2017 Sep 11 (America/Phoenix)
# time                                     [time unspecified or unknown]
# raw_date                                     2017-09-12 00:00:00 -0500
# month                                                                9
# year                                                              2017
# dateloc                                                              5
# trait                                          aboveground_dry_biomass
# trait_description                              Aboveground Dry Biomass
# mean                                                             37330
# units                                                          kg / ha
# n                                                                  NaN
# statname                                                           NaN
# stat                                                               NaN
# notes                                                              NaN
# access_level                                                         2
# cultivar                                                        SP1615
# entity                                                             NaN
# method_name                      Whole above ground biomass at harvest
# view_url             https://terraref.ncsa.illinois.edu/bety/traits...
# edit_url             https://terraref.ncsa.illinois.edu/bety/traits...
# Name: 864, dtype: object

# %%
# sitename - column 7
# trait - column 25
# mean - column 27
# units - column 28

# %%
# test_pivot_df = df2.pivot(index = 'sitename', columns = 'trait', values = ['mean', 'units'])
# test_pivot_df.head()

# %%
# inspect duplicates

duplicates = df2.duplicated(subset = ['sitename', 'trait'])

# %%
duplicates.value_counts()
# Out:
# True     358621
# False     13742
# dtype: int64

# %%
duplicates.head()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
# rows 1:5 - sitename, trait, mean, units

test_sample = df2.loc[1:5, ['sitename', 'trait', 'mean', 'units']]
test_sample
# Out:
#                                           sitename             trait    mean  \
# 1  MAC Field Scanner Season 4 Range 46 Column 14 E  leaf_temperature  305.05
# 2   MAC Field Scanner Season 4 Range 21 Column 8 W  leaf_temperature  306.25
# 3   MAC Field Scanner Season 4 Range 21 Column 8 W  leaf_temperature  306.45
# 4   MAC Field Scanner Season 4 Range 21 Column 8 W  leaf_temperature  306.55
# 5  MAC Field Scanner Season 4 Range 46 Column 14 E  leaf_temperature  307.65
#
#   units
# 1     K
# 2     K
# 3     K
# 4     K
# 5     K

# %%
# days to emergence
# days to flowering
# aboveground dry biomass

# %%
# aboveground dry biomass should only have been measured once per plot - at the end of harvest date
# check for duplicates 

dry_biomass_trait = df2.loc[df2['trait'] == 'aboveground_dry_biomass']
dry_biomass_trait.duplicated(subset = 'sitename').value_counts()
# Out:
# False    700
# dtype: int64

# %%
# days to flowering

flowering_time = df2.loc[df2['trait'] == 'flowering_time']
flowering_time.duplicated(subset = 'sitename').value_counts()
# Out:
# False    112
# dtype: int64

# %%
# days to emergence

flag_leaf_emergence = df2.loc[df2['trait'] == 'flag_leaf_emergence_time']
flag_leaf_emergence.duplicated(subset = 'sitename').value_counts()
# Out:
# False    122
# dtype: int64

# %%
# function(s) would be nice. . .

# %%
# calculate max canopy height with canopy_height on harvest date / latest date?

# %%
# s4 canopy height found in docs

s4_canopy_height = pd.read_csv('s4_canopy_height_formatted.csv')
s4_canopy_height.head()
# Out:
#    cultivar                                      sitename  day  canopy_height
# 0  PI330181  MAC Field Scanner Season 4 Range 3 Column 12   31             30
# 1  PI569447  MAC Field Scanner Season 4 Range 3 Column 13   31             27
# 2       NaN   MAC Field Scanner Season 4 Range 4 Column 2   31             27
# 3  PI329473   MAC Field Scanner Season 4 Range 4 Column 3   31             18
# 4  PI330169   MAC Field Scanner Season 4 Range 4 Column 8   31             35

# %%
s4_canopy_height.shape
# Out:
# (46673, 4)

# %%
test_check = df2.loc[df2['sitename'].str.contains('MAC Field Scanner Season 4 Range 3 Column 12')]

# %%
df2.iloc[371831]
# Out:
# Unnamed: 0                                                      371832
# checked                                                              0
# result_type                                                     traits
# id                                                          6004763087
# citation_id                                                      6e+09
# site_id                                                     6000005369
# treatment_id                                                       NaN
# sitename                  MAC Field Scanner Season 4 Range 3 Column 12
# city                                                          Maricopa
# lat                                                            33.0746
# lon                                                           -111.975
# scientificname                                         Sorghum bicolor
# commonname                                                     sorghum
# genus                                                          Sorghum
# species_id                                                        2588
# cultivar_id                                                 6000000685
# author                                                    Zongyang, Li
# citation_year                                                     2016
# treatment                                                          NaN
# date                                                        2017 May 6
# time                                        12:00:00 (America/Phoenix)
# raw_date                                     2017-05-06 14:00:00 -0500
# month                                                                5
# year                                                              2017
# dateloc                                                              5
# trait                                                    canopy_height
# trait_description    top of the general canopy of the plant, discou...
# mean                                                                12
# units                                                               cm
# n                                                                  NaN
# statname                                                           NaN
# stat                                                               NaN
# notes                                                              NaN
# access_level                                                         2
# cultivar                                                      PI152771
# entity                                                             NaN
# method_name                         3D scanner to 98th quantile height
# view_url             https://terraref.ncsa.illinois.edu/bety/traits...
# edit_url             https://terraref.ncsa.illinois.edu/bety/traits...
# Name: 371831, dtype: object

# %%
test_check.shape
# Out:
# (370, 39)

# %%
print(test_check.raw_date.max())
print(test_check.raw_date.min())
# Out:
# 2017-09-16 00:00:00 -0500
# 2017-04-26 00:00:00 -0500

# %%
test_check.loc[test_check.raw_date == test_check.raw_date.max()]['trait']
# Out:
# 868     aboveground_dry_biomass
# 2075        dry_matter_fraction
# 2246     harvest_lodging_rating
# Name: trait, dtype: object

# %%
# drop all rows that do not contain trait values for days to flowering, days to emergence, and aboveground dry biomass

selected_traits_only = df2[(df2['trait'] == 'aboveground_dry_biomass') | (df2['trait'] == 'flowering_time') | \
                          (df2['trait'] == 'flag_leaf_emergence_time')]

# %%
selected_traits_only.shape
# Out:
# (934, 39)

# %%
selected_traits_only.trait.unique()
# Out:
# array(['aboveground_dry_biomass', 'flowering_time',
#        'flag_leaf_emergence_time'], dtype=object)

# %%
selected_traits_only.columns
# Out:
# Index(['Unnamed: 0', 'checked', 'result_type', 'id', 'citation_id', 'site_id',
#        'treatment_id', 'sitename', 'city', 'lat', 'lon', 'scientificname',
#        'commonname', 'genus', 'species_id', 'cultivar_id', 'author',
#        'citation_year', 'treatment', 'date', 'time', 'raw_date', 'month',
#        'year', 'dateloc', 'trait', 'trait_description', 'mean', 'units', 'n',
#        'statname', 'stat', 'notes', 'access_level', 'cultivar', 'entity',
#        'method_name', 'view_url', 'edit_url'],
#       dtype='object')

# %%
selected_traits_only.head()
# Out:
#      Unnamed: 0  checked result_type          id   citation_id     site_id  \
# 864         865        0      traits  6001965127  6.000000e+09  6000005241
# 865         866        0      traits  6001965147  6.000000e+09  6000005237
# 866         867        0      traits  6001965192  6.000000e+09  6000005345
# 867         868        0      traits  6001965202  6.000000e+09  6000005351
# 868         869        0      traits  6001965232  6.000000e+09  6000005369
#
#      treatment_id                                      sitename      city  \
# 864  6.000000e+09   MAC Field Scanner Season 4 Range 2 Column 5  Maricopa
# 865  6.000000e+09   MAC Field Scanner Season 4 Range 2 Column 9  Maricopa
# 866  6.000000e+09   MAC Field Scanner Season 4 Range 3 Column 4  Maricopa
# 867  6.000000e+09   MAC Field Scanner Season 4 Range 3 Column 6  Maricopa
# 868  6.000000e+09  MAC Field Scanner Season 4 Range 3 Column 12  Maricopa
#
#            lat  ...   n statname stat notes  access_level  cultivar entity  \
# 864  33.074584  ... NaN      NaN  NaN   NaN             2    SP1615    NaN
# 865  33.074584  ... NaN      NaN  NaN   NaN             2    SP1615    NaN
# 866  33.074619  ... NaN      NaN  NaN   NaN             2  PI145626    NaN
# 867  33.074620  ... NaN      NaN  NaN   NaN             2  PI330181    NaN
# 868  33.074620  ... NaN      NaN  NaN   NaN             2  PI152771    NaN
#
#                                method_name  \
# 864  Whole above ground biomass at harvest
# 865  Whole above ground biomass at harvest
# 866  Whole above ground biomass at harvest
# 867  Whole above ground biomass at harvest
# 868  Whole above ground biomass at harvest
#
#                                               view_url  \
# 864  https://terraref.ncsa.illinois.edu/bety/traits...
# 865  https://terraref.ncsa.illinois.edu/bety/traits...
# 866  https://terraref.ncsa.illinois.edu/bety/traits...
# 867  https://terraref.ncsa.illinois.edu/bety/traits...
# 868  https://terraref.ncsa.illinois.edu/bety/traits...
#
#                                               edit_url
# 864  https://terraref.ncsa.illinois.edu/bety/traits...
# 865  https://terraref.ncsa.illinois.edu/bety/traits...
# 866  https://terraref.ncsa.illinois.edu/bety/traits...
# 867  https://terraref.ncsa.illinois.edu/bety/traits...
# 868  https://terraref.ncsa.illinois.edu/bety/traits...
#
# [5 rows x 39 columns]

# %%
selected_traits_only.iloc[868]
# Out:
# Unnamed: 0                                                      302733
# checked                                                              0
# result_type                                                     traits
# id                                                          6001968013
# citation_id                                                      6e+09
# site_id                                                     6000005911
# treatment_id                                                     6e+09
# sitename                 MAC Field Scanner Season 4 Range 43 Column 14
# city                                                          Maricopa
# lat                                                            33.0761
# lon                                                           -111.975
# scientificname                                         Sorghum bicolor
# commonname                                                     sorghum
# genus                                                          Sorghum
# species_id                                                        2588
# cultivar_id                                                 6000000924
# author                                                  Newcomb, Maria
# citation_year                                                     2017
# treatment                      BAP 2017, water-deficit stress Aug 1-14
# date                                     2017 Sep 15 (America/Phoenix)
# time                                     [time unspecified or unknown]
# raw_date                                     2017-09-16 00:00:00 -0500
# month                                                                9
# year                                                              2017
# dateloc                                                              5
# trait                                          aboveground_dry_biomass
# trait_description                              Aboveground Dry Biomass
# mean                                                             23000
# units                                                          kg / ha
# n                                                                  NaN
# statname                                                           NaN
# stat                                                               NaN
# notes                                                              NaN
# access_level                                                         2
# cultivar                                                      PI569427
# entity                                                             NaN
# method_name                      Whole above ground biomass at harvest
# view_url             https://terraref.ncsa.illinois.edu/bety/traits...
# edit_url             https://terraref.ncsa.illinois.edu/bety/traits...
# Name: 302732, dtype: object

# %%
print(selected_traits_only.city.unique())
print(selected_traits_only.id.nunique())
print(selected_traits_only.citation_id.nunique())
print(selected_traits_only.site_id.nunique())
print(selected_traits_only.lat.nunique())
print(selected_traits_only.scientificname.nunique())
print(selected_traits_only.species_id.nunique())
print(selected_traits_only.cultivar_id.nunique())
print(selected_traits_only.trait_description.unique())
print(selected_traits_only.n.unique())
print(selected_traits_only.notes.unique())
print(selected_traits_only.cultivar.nunique())
print(selected_traits_only.method_name.unique())
# Out:
# ['Maricopa']
# 934
# 1
# 708
# 708
# 1
# 1
# 351
# ['Aboveground Dry Biomass'
#  'Number of days from sowing to the date when 50% of the plants in a plot reach flowering (anthesis), defined as the time when 50% of the anthers on 50% of the plants in a plot have emerged.'
#  'Number days from sowing to the date when 50% of the plants in a plot have reached flag leaf emergence (ligulation) stage. Flag leaf is the last leaf to emerge from the whorl, positioned directly below the panicle.']
# [nan]
# [nan]
# 351
# ['Whole above ground biomass at harvest'
#  'Visual classification of sorghum growth stages to determine estimates of developmental timing']

# %%
selected_traits_only.shape
# Out:
# (934, 39)

# %%
cols_to_drop = ['Unnamed: 0', 'checked', 'result_type', 'citation_id', 'scientificname', 'species_id', 'author', \
               'citation_year', 'treatment', 'date', 'month', 'year', 'dateloc', 'n', 'statname', 'stat', 'notes', \
               'access_level', 'entity', 'method_name', 'view_url', 'edit_url', 'treatment_id', 'city', 'commonname', \
               'genus', 'time', 'raw_date']

selected_and_dropped = selected_traits_only.drop(labels = cols_to_drop, axis = 1)

# %%
selected_and_dropped.head()
# Out:
#              id     site_id                                      sitename  \
# 864  6001965127  6000005241   MAC Field Scanner Season 4 Range 2 Column 5
# 865  6001965147  6000005237   MAC Field Scanner Season 4 Range 2 Column 9
# 866  6001965192  6000005345   MAC Field Scanner Season 4 Range 3 Column 4
# 867  6001965202  6000005351   MAC Field Scanner Season 4 Range 3 Column 6
# 868  6001965232  6000005369  MAC Field Scanner Season 4 Range 3 Column 12
#
#            lat         lon  cultivar_id                    trait  \
# 864  33.074584 -111.974982   6000001054  aboveground_dry_biomass
# 865  33.074584 -111.974917   6000001054  aboveground_dry_biomass
# 866  33.074619 -111.974998   6000000462  aboveground_dry_biomass
# 867  33.074620 -111.974966   6000000818  aboveground_dry_biomass
# 868  33.074620 -111.974867   6000000685  aboveground_dry_biomass
#
#            trait_description     mean    units  cultivar
# 864  Aboveground Dry Biomass  37330.0  kg / ha    SP1615
# 865  Aboveground Dry Biomass  36900.0  kg / ha    SP1615
# 866  Aboveground Dry Biomass  23190.0  kg / ha  PI145626
# 867  Aboveground Dry Biomass  30150.0  kg / ha  PI330181
# 868  Aboveground Dry Biomass  21990.0  kg / ha  PI152771

# %%
selected_and_dropped.shape
# Out:
# (934, 11)

# %%
# Check for duplicates

selected_and_dropped.duplicated(subset = ['site_id', 'sitename', 'trait_description']).value_counts()
# Out:
# False    934
# dtype: int64

# %%
selected_and_dropped.to_csv('selected_traits_with_cultivar_and_site_ids.csv', index = False)

# %%
print(selected_and_dropped.trait.unique())
print(selected_and_dropped.trait_description.unique())
print(selected_and_dropped.units.unique())
# Out:
# ['aboveground_dry_biomass' 'flowering_time' 'flag_leaf_emergence_time']
# ['Aboveground Dry Biomass'
#  'Number of days from sowing to the date when 50% of the plants in a plot reach flowering (anthesis), defined as the time when 50% of the anthers on 50% of the plants in a plot have emerged.'
#  'Number days from sowing to the date when 50% of the plants in a plot have reached flag leaf emergence (ligulation) stage. Flag leaf is the last leaf to emerge from the whorl, positioned directly below the panicle.']
# ['kg / ha' 'days']

# %%
id_cols_to_drop = ['id', 'site_id', 'lat', 'lon', 'cultivar_id', 'trait_description', 'units']
bare_bones_df = selected_and_dropped.drop(labels = id_cols_to_drop, axis = 1)

# %%
bare_bones_df.tail()
# Out:
#                                              sitename  \
# 304147   MAC Field Scanner Season 4 Range 20 Column 4
# 304158  MAC Field Scanner Season 4 Range 20 Column 15
# 304159   MAC Field Scanner Season 4 Range 30 Column 4
# 304164  MAC Field Scanner Season 4 Range 30 Column 11
# 304167  MAC Field Scanner Season 4 Range 30 Column 12
#
#                           trait     mean  cultivar
# 304147  aboveground_dry_biomass  12220.0  PI526905
# 304158  aboveground_dry_biomass  10480.0  PI152828
# 304159  aboveground_dry_biomass  17260.0  PI569416
# 304164  aboveground_dry_biomass  14990.0  PI563022
# 304167  aboveground_dry_biomass  20100.0  PI568717

# %%
print(bare_bones_df.sitename.nunique())
print(bare_bones_df.cultivar.nunique())
print(bare_bones_df.trait.nunique())
# Out:
# 708
# 351
# 3

# %%
# two indices?

site_cultivar_indices = pd.pivot_table(data = bare_bones_df, index = ['sitename', 'cultivar'], columns = 'trait',
                                      values = 'mean')

# %%
site_cultivar_indices.head()
# Out:
# trait                                                   aboveground_dry_biomass  \
# sitename                                      cultivar
# MAC Field Scanner Season 4 Range 10 Column 10 PI152816                  24040.0
# MAC Field Scanner Season 4 Range 10 Column 11 PI195754                  29400.0
# MAC Field Scanner Season 4 Range 10 Column 12 PI329501                  12180.0
# MAC Field Scanner Season 4 Range 10 Column 13 PI641860                  35400.0
# MAC Field Scanner Season 4 Range 10 Column 14 PI19770                   19660.0
#
# trait                                                   flag_leaf_emergence_time  \
# sitename                                      cultivar
# MAC Field Scanner Season 4 Range 10 Column 10 PI152816                       NaN
# MAC Field Scanner Season 4 Range 10 Column 11 PI195754                       NaN
# MAC Field Scanner Season 4 Range 10 Column 12 PI329501                       NaN
# MAC Field Scanner Season 4 Range 10 Column 13 PI641860                      91.0
# MAC Field Scanner Season 4 Range 10 Column 14 PI19770                        NaN
#
# trait                                                   flowering_time
# sitename                                      cultivar
# MAC Field Scanner Season 4 Range 10 Column 10 PI152816             NaN
# MAC Field Scanner Season 4 Range 10 Column 11 PI195754             NaN
# MAC Field Scanner Season 4 Range 10 Column 12 PI329501             NaN
# MAC Field Scanner Season 4 Range 10 Column 13 PI641860             NaN
# MAC Field Scanner Season 4 Range 10 Column 14 PI19770              NaN

# %%
site_cultivar_indices.shape
# Out:
# (708, 3)

# %%
site_cultivar_indices.to_csv('site_cultivar_indices.csv')

# %%
print(bare_bones_df.shape)
print(bare_bones_df.sitename.nunique())
print(bare_bones_df.cultivar.nunique())
# Out:
# (934, 4)
# 708
# 351

# %%
minus_cultivar = bare_bones_df.drop(columns = 'cultivar', axis = 1)

# %%
minus_cultivar.head()
# Out:
#                                          sitename                    trait  \
# 864   MAC Field Scanner Season 4 Range 2 Column 5  aboveground_dry_biomass
# 865   MAC Field Scanner Season 4 Range 2 Column 9  aboveground_dry_biomass
# 866   MAC Field Scanner Season 4 Range 3 Column 4  aboveground_dry_biomass
# 867   MAC Field Scanner Season 4 Range 3 Column 6  aboveground_dry_biomass
# 868  MAC Field Scanner Season 4 Range 3 Column 12  aboveground_dry_biomass
#
#         mean
# 864  37330.0
# 865  36900.0
# 866  23190.0
# 867  30150.0
# 868  21990.0

# %%
cultivar_and_sitename = bare_bones_df[['sitename', 'cultivar']]
cultivar_and_sitename.head()
# Out:
#                                          sitename  cultivar
# 864   MAC Field Scanner Season 4 Range 2 Column 5    SP1615
# 865   MAC Field Scanner Season 4 Range 2 Column 9    SP1615
# 866   MAC Field Scanner Season 4 Range 3 Column 4  PI145626
# 867   MAC Field Scanner Season 4 Range 3 Column 6  PI330181
# 868  MAC Field Scanner Season 4 Range 3 Column 12  PI152771

# %%
cultivar_and_sitename.set_index('sitename')
cultivar_and_sitename.head()
# Out:
#                                          sitename  cultivar
# 864   MAC Field Scanner Season 4 Range 2 Column 5    SP1615
# 865   MAC Field Scanner Season 4 Range 2 Column 9    SP1615
# 866   MAC Field Scanner Season 4 Range 3 Column 4  PI145626
# 867   MAC Field Scanner Season 4 Range 3 Column 6  PI330181
# 868  MAC Field Scanner Season 4 Range 3 Column 12  PI152771

# %%
wide_df = minus_cultivar.pivot(index = 'sitename', columns = 'trait', values = 'mean')
wide_df.head()
# Out:
# trait                                          aboveground_dry_biomass  \
# sitename
# MAC Field Scanner Season 4 Range 10 Column 10                  24040.0
# MAC Field Scanner Season 4 Range 10 Column 11                  29400.0
# MAC Field Scanner Season 4 Range 10 Column 12                  12180.0
# MAC Field Scanner Season 4 Range 10 Column 13                  35400.0
# MAC Field Scanner Season 4 Range 10 Column 14                  19660.0
#
# trait                                          flag_leaf_emergence_time  \
# sitename
# MAC Field Scanner Season 4 Range 10 Column 10                       NaN
# MAC Field Scanner Season 4 Range 10 Column 11                       NaN
# MAC Field Scanner Season 4 Range 10 Column 12                       NaN
# MAC Field Scanner Season 4 Range 10 Column 13                      91.0
# MAC Field Scanner Season 4 Range 10 Column 14                       NaN
#
# trait                                          flowering_time
# sitename
# MAC Field Scanner Season 4 Range 10 Column 10             NaN
# MAC Field Scanner Season 4 Range 10 Column 11             NaN
# MAC Field Scanner Season 4 Range 10 Column 12             NaN
# MAC Field Scanner Season 4 Range 10 Column 13             NaN
# MAC Field Scanner Season 4 Range 10 Column 14             NaN

# %%
# merge with cultivars

concat_df = pd.concat([wide_df, cultivar_and_sitename], )
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
concat_df.head()
# Out:
#                                                aboveground_dry_biomass  \
# MAC Field Scanner Season 4 Range 10 Column 10                  24040.0
# MAC Field Scanner Season 4 Range 10 Column 11                  29400.0
# MAC Field Scanner Season 4 Range 10 Column 12                  12180.0
# MAC Field Scanner Season 4 Range 10 Column 13                  35400.0
# MAC Field Scanner Season 4 Range 10 Column 14                  19660.0
#
#                                               cultivar  \
# MAC Field Scanner Season 4 Range 10 Column 10      NaN
# MAC Field Scanner Season 4 Range 10 Column 11      NaN
# MAC Field Scanner Season 4 Range 10 Column 12      NaN
# MAC Field Scanner Season 4 Range 10 Column 13      NaN
# MAC Field Scanner Season 4 Range 10 Column 14      NaN
#
#                                                flag_leaf_emergence_time  \
# MAC Field Scanner Season 4 Range 10 Column 10                       NaN
# MAC Field Scanner Season 4 Range 10 Column 11                       NaN
# MAC Field Scanner Season 4 Range 10 Column 12                       NaN
# MAC Field Scanner Season 4 Range 10 Column 13                      91.0
# MAC Field Scanner Season 4 Range 10 Column 14                       NaN
#
#                                                flowering_time sitename
# MAC Field Scanner Season 4 Range 10 Column 10             NaN      NaN
# MAC Field Scanner Season 4 Range 10 Column 11             NaN      NaN
# MAC Field Scanner Season 4 Range 10 Column 12             NaN      NaN
# MAC Field Scanner Season 4 Range 10 Column 13             NaN      NaN
# MAC Field Scanner Season 4 Range 10 Column 14             NaN      NaN

# %%
concat_df.cultivar.nunique()
# Out:
# 351

# %%
concat_df.cultivar.count()
# Out:
# 934

# %%
site_cultivar_df = pd.read_csv('site_cultivar_indices.csv')
site_cultivar_df.head()
# Out:
#                                         sitename  cultivar  \
# 0  MAC Field Scanner Season 4 Range 10 Column 10  PI152816
# 1  MAC Field Scanner Season 4 Range 10 Column 11  PI195754
# 2  MAC Field Scanner Season 4 Range 10 Column 12  PI329501
# 3  MAC Field Scanner Season 4 Range 10 Column 13  PI641860
# 4  MAC Field Scanner Season 4 Range 10 Column 14   PI19770
#
#    aboveground_dry_biomass  flag_leaf_emergence_time  flowering_time
# 0                  24040.0                       NaN             NaN
# 1                  29400.0                       NaN             NaN
# 2                  12180.0                       NaN             NaN
# 3                  35400.0                      91.0             NaN
# 4                  19660.0                       NaN             NaN

# %%
filled_nas = site_cultivar_df.fillna(value='')
filled_nas.head()
# Out:
#                                         sitename  cultivar  \
# 0  MAC Field Scanner Season 4 Range 10 Column 10  PI152816
# 1  MAC Field Scanner Season 4 Range 10 Column 11  PI195754
# 2  MAC Field Scanner Season 4 Range 10 Column 12  PI329501
# 3  MAC Field Scanner Season 4 Range 10 Column 13  PI641860
# 4  MAC Field Scanner Season 4 Range 10 Column 14   PI19770
#
#   aboveground_dry_biomass flag_leaf_emergence_time flowering_time
# 0                   24040
# 1                   29400
# 2                   12180
# 3                   35400                       91
# 4                   19660

# %%
filled_nas.sample(n=50, random_state=42)
# Out:
#                                           sitename    cultivar  \
# 120   MAC Field Scanner Season 4 Range 18 Column 4    PI540518
# 247  MAC Field Scanner Season 4 Range 27 Column 11    PI641810
# 324  MAC Field Scanner Season 4 Range 32 Column 13    PI585966
# 204  MAC Field Scanner Season 4 Range 24 Column 10    PI570106
# 603   MAC Field Scanner Season 4 Range 50 Column 3    PI656015
# 356   MAC Field Scanner Season 4 Range 34 Column 5    PI153877
# 81    MAC Field Scanner Season 4 Range 15 Column 7    PI152971
# 54    MAC Field Scanner Season 4 Range 13 Column 8    PI329480
# 512   MAC Field Scanner Season 4 Range 44 Column 9    PI329286
# 572  MAC Field Scanner Season 4 Range 49 Column 13    PI569886
# 457   MAC Field Scanner Season 4 Range 40 Column 9    PI563329
# 212   MAC Field Scanner Season 4 Range 24 Column 4    PI585577
# 78    MAC Field Scanner Season 4 Range 15 Column 4    PI156890
# 411   MAC Field Scanner Season 4 Range 38 Column 4    PI175919
# 543  MAC Field Scanner Season 4 Range 47 Column 12    PI156178
# 39    MAC Field Scanner Season 4 Range 12 Column 7    PI213900
# 412   MAC Field Scanner Season 4 Range 38 Column 5    PI329326
# 548   MAC Field Scanner Season 4 Range 47 Column 3    PI455221
# 84   MAC Field Scanner Season 4 Range 16 Column 10    PI569465
# 327   MAC Field Scanner Season 4 Range 32 Column 2    PI152961
# 109   MAC Field Scanner Season 4 Range 17 Column 7    PI157030
# 145    MAC Field Scanner Season 4 Range 2 Column 2  Big_Kahuna
# 234  MAC Field Scanner Season 4 Range 26 Column 12    PI156330
# 649   MAC Field Scanner Season 4 Range 53 Column 7      SP1615
# 63    MAC Field Scanner Season 4 Range 14 Column 3    PI505717
# 362  MAC Field Scanner Season 4 Range 35 Column 11    PI152651
# 49    MAC Field Scanner Season 4 Range 13 Column 3    PI330833
# 426   MAC Field Scanner Season 4 Range 39 Column 5    PI570076
# 398   MAC Field Scanner Season 4 Range 37 Column 5    PI569435
# 220  MAC Field Scanner Season 4 Range 25 Column 12    PI273969
# 611  MAC Field Scanner Season 4 Range 51 Column 11    PI563002
# 340   MAC Field Scanner Season 4 Range 33 Column 2    PI181080
# 135   MAC Field Scanner Season 4 Range 19 Column 6    PI330185
# 500  MAC Field Scanner Season 4 Range 44 Column 11    PI505717
# 260  MAC Field Scanner Season 4 Range 28 Column 10    PI273465
# 523   MAC Field Scanner Season 4 Range 45 Column 6    PI152730
# 333   MAC Field Scanner Season 4 Range 32 Column 9    PI152862
# 101  MAC Field Scanner Season 4 Range 17 Column 13    PI586541
# 210   MAC Field Scanner Season 4 Range 24 Column 2    PI641815
# 77    MAC Field Scanner Season 4 Range 15 Column 3    PI570114
# 353   MAC Field Scanner Season 4 Range 34 Column 2    PI569454
# 608   MAC Field Scanner Season 4 Range 50 Column 8    PI593916
# 192  MAC Field Scanner Season 4 Range 23 Column 12    PI297130
# 118   MAC Field Scanner Season 4 Range 18 Column 2    PI570042
# 518  MAC Field Scanner Season 4 Range 45 Column 15    PI563021
# 235  MAC Field Scanner Season 4 Range 26 Column 13    PI453696
# 688    MAC Field Scanner Season 4 Range 8 Column 4    PI329584
# 634   MAC Field Scanner Season 4 Range 52 Column 6    PI152751
# 286   MAC Field Scanner Season 4 Range 3 Column 10    PI569097
# 654   MAC Field Scanner Season 4 Range 6 Column 12    PI329517
#
#     aboveground_dry_biomass flag_leaf_emergence_time flowering_time
# 120                   11840                       70             72
# 247                   30420                       72             74
# 324                   12110
# 204                   26370
# 603                                               50             58
# 356                   33190
# 81                    28380
# 54                    11580
# 512                    6628
# 572                   22020
# 457                   27030
# 212                   15640
# 78                    16670
# 411                   16630                       62             70
# 543                   22000
# 39                    14250                       50             54
# 412                   21180
# 548                   41520
# 84                    10310
# 327                   17160
# 109                   32720
# 145                   15910
# 234                   14060
# 649                   31570
# 63                    20780
# 362                    7158
# 49                    16430
# 426                   24040
# 398                   10850
# 220                   46300
# 611                   18960
# 340                    6158                       49             54
# 135                   52200
# 500                   27290
# 260                   23710
# 523                   29500                       77
# 333                   27020
# 101                   22810
# 210                   23130                       77             89
# 77                    14550
# 353                   14050
# 608                   37150                       58             63
# 192                   34340
# 118                    9693
# 518                   24220
# 235                   25600
# 688                    5968
# 634                   30780
# 286                   25140
# 654                   19820

# %%
filled_nas_sample = filled_nas.sample(n=50, random_state=43)
filled_nas_sample.tail()
# Out:
#                                           sitename  cultivar  \
# 273  MAC Field Scanner Season 4 Range 29 Column 11  PI329501
# 19   MAC Field Scanner Season 4 Range 11 Column 15  PI535796
# 577   MAC Field Scanner Season 4 Range 49 Column 5  PI653616
# 67    MAC Field Scanner Season 4 Range 14 Column 7  PI329618
# 611  MAC Field Scanner Season 4 Range 51 Column 11  PI563002
#
#     aboveground_dry_biomass flag_leaf_emergence_time flowering_time
# 273                   20730
# 19                    23100                       62             68
# 577                   25790
# 67                     7152
# 611                   18960

# %%
filled_nas_sample.to_csv('sample_subset_season_4.csv', index=False)

# %%
filled_nas.to_csv('transformed_data_season_4.csv', index=False)

# %% [markdown]
# #### Need Max Canopy Height

# %%
season_four = pd.read_csv('mac_season_4.csv')
season_four.head()
# Out:
# /opt/miniconda3/envs/ua-ag/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (18,26,32,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  checked result_type          id   citation_id     site_id  \
# 0           1        0      traits  6001958927  6.000000e+09  6000005673
# 1           2        0      traits  6001958928  6.000000e+09  6000005676
# 2           3        0      traits  6001958931  6.000000e+09  6000005685
# 3           4        0      traits  6001958933  6.000000e+09  6000005691
# 4           5        0      traits  6001958936  6.000000e+09  6000005700
#
#    treatment_id                                       sitename      city  \
# 0  6.000000e+09   MAC Field Scanner Season 4 Range 11 Column 5  Maricopa
# 1  6.000000e+09   MAC Field Scanner Season 4 Range 11 Column 6  Maricopa
# 2  6.000000e+09   MAC Field Scanner Season 4 Range 11 Column 9  Maricopa
# 3  6.000000e+09  MAC Field Scanner Season 4 Range 11 Column 11  Maricopa
# 4  6.000000e+09  MAC Field Scanner Season 4 Range 11 Column 14  Maricopa
#
#          lat  ...   n statname stat notes  access_level  cultivar entity  \
# 0  33.074907  ... NaN      NaN  NaN   NaN             2  PI181083    NaN
# 1  33.074907  ... NaN      NaN  NaN   NaN             2  PI564163    NaN
# 2  33.074907  ... NaN      NaN  NaN   NaN             2   PI52606    NaN
# 3  33.074907  ... NaN      NaN  NaN   NaN             2  PI533792    NaN
# 4  33.074907  ... NaN      NaN  NaN   NaN             2  PI535794    NaN
#
#                              method_name  \
# 0  Visual assessment of leaf dessication
# 1  Visual assessment of leaf dessication
# 2  Visual assessment of leaf dessication
# 3  Visual assessment of leaf dessication
# 4  Visual assessment of leaf dessication
#
#                                             view_url  \
# 0  https://terraref.ncsa.illinois.edu/bety/traits...
# 1  https://terraref.ncsa.illinois.edu/bety/traits...
# 2  https://terraref.ncsa.illinois.edu/bety/traits...
# 3  https://terraref.ncsa.illinois.edu/bety/traits...
# 4  https://terraref.ncsa.illinois.edu/bety/traits...
#
#                                             edit_url
# 0  https://terraref.ncsa.illinois.edu/bety/traits...
# 1  https://terraref.ncsa.illinois.edu/bety/traits...
# 2  https://terraref.ncsa.illinois.edu/bety/traits...
# 3  https://terraref.ncsa.illinois.edu/bety/traits...
# 4  https://terraref.ncsa.illinois.edu/bety/traits...
#
# [5 rows x 39 columns]

# %%
season_four.trait.unique()
# Out:
# array(['leaf_desiccation_present', 'lodging_present', 'leaf_temperature',
#        'planter_seed_drop', 'roll', 'PhiNO', 'PhiNPQ', 'absorbance_530',
#        'absorbance_605', 'absorbance_730', 'absorbance_880',
#        'absorbance_940', 'Fs', 'NPQt', 'qL', 'qP', 'RFd', 'SPAD_530',
#        'SPAD_605', 'SPAD_730', 'leaf_thickness', 'ambient_humidity',
#        'leaf_angle_clamp_position', 'pitch', 'proximal_air_temperature',
#        'FvP/FmP', 'gH+', 'ECSt', 'leaf_temperature_differential', 'Phi2',
#        'relative_chlorophyll', 'FmPrime', 'FoPrime', 'LEF', 'SPAD_420',
#        'SPAD_650', 'SPAD_850', 'SPAD_880', 'light_intensity_PAR', 'vH+',
#        'absorbance_650', 'absorbance_850', 'absorbance_420',
#        'surface_temperature', 'leaf_angle_chi', 'leaf_angle_mean',
#        'leaf_angle_alpha', 'leaf_angle_beta', 'aboveground_dry_biomass',
#        'seedling_emergence_rate', 'panicle_height', 'stand_count',
#        'dry_matter_fraction', 'harvest_lodging_rating', 'canopy_height',
#        'anthocyanin_index', 'chlorophyll_index',
#        'flag_leaf_emergence_time', 'flowering_time', 'grain_stage_time',
#        'leaf_length', 'leaf_width', 'leaf_stomatal_conductance',
#        'aboveground_biomass_moisture', 'aboveground_fresh_biomass',
#        'canopy_cover', 'panicle_count', 'panicle_volume',
#        'panicle_surface_area', 'stem_elongated_internodes_number',
#        'emergence_count', 'stalk_diameter_fixed_height',
#        'stalk_diameter_minor_axis', 'stalk_diameter_major_axis',
#        'plant_basal_tiller_number'], dtype=object)

# %%
canopy_height = season_four.loc[season_four.trait == 'canopy_height']
canopy_height.shape
# Out:
# (58056, 39)

# %%
# drop similar columns to above but keep date cols for now

cols_to_drop = ['Unnamed: 0', 'checked', 'result_type', 'citation_id', 'scientificname', 'species_id', 'author', \
                'citation_year', 'treatment', 'n', 'statname', 'stat', 'notes', 'access_level', 'entity', \
                'method_name', 'view_url', 'edit_url', 'treatment_id', 'city', 'commonname', 'genus', 'id', \
               'site_id', 'lat', 'lon', 'cultivar_id']

dropped_col_df = canopy_height.drop(labels=cols_to_drop, axis=1)
dropped_col_df.head()
# Out:
#                                               sitename  \
# 51339   MAC Field Scanner Season 4 Range 30 Column 9 E
# 51340  MAC Field Scanner Season 4 Range 20 Column 15 W
# 51341  MAC Field Scanner Season 4 Range 20 Column 15 W
# 75000    MAC Field Scanner Season 4 Range 35 Column 14
# 75001     MAC Field Scanner Season 4 Range 36 Column 2
#
#                                 date                           time  \
# 51339  2017 Jun 19 (America/Phoenix)  [time unspecified or unknown]
# 51340   2017 Jun 4 (America/Phoenix)  [time unspecified or unknown]
# 51341  2017 May 29 (America/Phoenix)  [time unspecified or unknown]
# 75000                    2017 May 20     12:00:00 (America/Phoenix)
# 75001                    2017 May 20     12:00:00 (America/Phoenix)
#
#                         raw_date  month  year  dateloc          trait  \
# 51339  2017-06-20 00:00:00 -0500      6  2017      5.0  canopy_height
# 51340  2017-06-05 00:00:00 -0500      6  2017      5.0  canopy_height
# 51341  2017-05-30 00:00:00 -0500      5  2017      5.0  canopy_height
# 75000  2017-05-20 14:00:00 -0500      5  2017      5.0  canopy_height
# 75001  2017-05-20 14:00:00 -0500      5  2017      5.0  canopy_height
#
#                                        trait_description  mean units  cultivar
# 51339  top of the general canopy of the plant, discou...  91.0    cm  PI329518
# 51340  top of the general canopy of the plant, discou...  99.0    cm  PI152828
# 51341  top of the general canopy of the plant, discou...  63.0    cm  PI152828
# 75000  top of the general canopy of the plant, discou...  22.0    cm  PI619838
# 75001  top of the general canopy of the plant, discou...  26.0    cm  PI155885

# %%
dropped_col_df.trait_description.unique()
# Out:
# array(['top of the general canopy of the plant, discounting any exceptional branches, leaves or photosynthetic portions of the inflorescence.'],
#       dtype=object)

# %%
dropped_col_df.duplicated(subset='sitename')
# Out:
# 51339     False
# 51340     False
# 51341      True
# 75000     False
# 75001     False
#           ...
# 354995     True
# 354996     True
# 354997     True
# 354998     True
# 354999     True
# Length: 58056, dtype: bool

# %%
test_df = dropped_col_df.drop(labels=['time', 'dateloc', 'trait_description'], axis=1)

# %%
# remove _E and _W from all sitenames
# need logical test - if duplicate sitenames, then only use the measurement from the latest date
# function to find latest date?

# %%
test_string = ['blah blah', 'blah blah W', 'blah blah X', 'blahblahblah', 'blah blah E']

new_string

for i in test_string:
    
    if i.endswith(' W'):
        i = i[:-2]
        new_string.append(i)
    
    elif i.endswith(' E'):
        i = i[:-2]  
        new_string.append(i)
    
    else:
        new_string.append(i)

new_string
# Out:
# ['blah blah',
#  'blah blah',
#  'blah blah',
#  'blah blah X',
#  'blahblahblah',
#  'blah blah']

# %%
test_series = pd.Series(data = test_string)
test_series
# Out:
# 0       blah blah
# 1     blah blah W
# 2     blah blah X
# 3    blahblahblah
# 4     blah blah E
# dtype: object

# %%
# will need to use pandas function 'where' rather than a for-loop

# filter_e = !test_series.endswith(' E')
# filter_w = !test_series.endswith(' W')

# test_series = test_series.where(filter_e or filter_w, test_series[:-2])
# test_series

# %%
test_values = test_series.values
test_values
# Out:
# array(['blah blah', 'blah blah W', 'blah blah X', 'blahblahblah',
#        'blah blah E'], dtype=object)

# %%
new_values = []

for val in test_values:
    if val.endswith(' W'):
        val = val[:-2]
        new_values.append(val)
        
    elif val.endswith(' E'):
        val = val[:-2]
        new_values.append(val)
        
    else:
        new_values.append(val)
        
new_values
# Out:
# ['blah blah', 'blah blah', 'blah blah X', 'blahblahblah', 'blah blah']

# %%
test_df.head()
# Out:
#                                               sitename  \
# 51339   MAC Field Scanner Season 4 Range 30 Column 9 E
# 51340  MAC Field Scanner Season 4 Range 20 Column 15 W
# 51341  MAC Field Scanner Season 4 Range 20 Column 15 W
# 75000    MAC Field Scanner Season 4 Range 35 Column 14
# 75001     MAC Field Scanner Season 4 Range 36 Column 2
#
#                                 date                   raw_date  month  year  \
# 51339  2017 Jun 19 (America/Phoenix)  2017-06-20 00:00:00 -0500      6  2017
# 51340   2017 Jun 4 (America/Phoenix)  2017-06-05 00:00:00 -0500      6  2017
# 51341  2017 May 29 (America/Phoenix)  2017-05-30 00:00:00 -0500      5  2017
# 75000                    2017 May 20  2017-05-20 14:00:00 -0500      5  2017
# 75001                    2017 May 20  2017-05-20 14:00:00 -0500      5  2017
#
#                trait  mean units  cultivar
# 51339  canopy_height  91.0    cm  PI329518
# 51340  canopy_height  99.0    cm  PI152828
# 51341  canopy_height  63.0    cm  PI152828
# 75000  canopy_height  22.0    cm  PI619838
# 75001  canopy_height  26.0    cm  PI155885

# %%
sitenames = test_df.sitename.values
sitenames[:10]
# Out:
# array(['MAC Field Scanner Season 4 Range 30 Column 9 E',
#        'MAC Field Scanner Season 4 Range 20 Column 15 W',
#        'MAC Field Scanner Season 4 Range 20 Column 15 W',
#        'MAC Field Scanner Season 4 Range 35 Column 14',
#        'MAC Field Scanner Season 4 Range 36 Column 2',
#        'MAC Field Scanner Season 4 Range 36 Column 3',
#        'MAC Field Scanner Season 4 Range 36 Column 5',
#        'MAC Field Scanner Season 4 Range 36 Column 6',
#        'MAC Field Scanner Season 4 Range 36 Column 7',
#        'MAC Field Scanner Season 4 Range 36 Column 9'], dtype=object)

# %%
new_sitenames = []

for site in sitenames:
    if site.endswith(' W'):
        site = site[:-2]
        new_sitenames.append(site)
        
    elif site.endswith(' E'):
        site = site[:-2]
        new_sitenames.append(site)
        
    else:
        new_sitenames.append(site)
        
new_sitenames[:10]
# Out:
# ['MAC Field Scanner Season 4 Range 30 Column 9',
#  'MAC Field Scanner Season 4 Range 20 Column 15',
#  'MAC Field Scanner Season 4 Range 20 Column 15',
#  'MAC Field Scanner Season 4 Range 35 Column 14',
#  'MAC Field Scanner Season 4 Range 36 Column 2',
#  'MAC Field Scanner Season 4 Range 36 Column 3',
#  'MAC Field Scanner Season 4 Range 36 Column 5',
#  'MAC Field Scanner Season 4 Range 36 Column 6',
#  'MAC Field Scanner Season 4 Range 36 Column 7',
#  'MAC Field Scanner Season 4 Range 36 Column 9']

# %%
print(len(test_df.sitename))
print(len(new_sitenames))
# Out:
# 58056
# 58056

# %%
new_test_df = test_df.drop(labels='sitename', axis=1)
new_test_df['new_sitename'] = new_sitenames

# %%
new_test_df.head()
# Out:
#                                 date                   raw_date  month  year  \
# 51339  2017 Jun 19 (America/Phoenix)  2017-06-20 00:00:00 -0500      6  2017
# 51340   2017 Jun 4 (America/Phoenix)  2017-06-05 00:00:00 -0500      6  2017
# 51341  2017 May 29 (America/Phoenix)  2017-05-30 00:00:00 -0500      5  2017
# 75000                    2017 May 20  2017-05-20 14:00:00 -0500      5  2017
# 75001                    2017 May 20  2017-05-20 14:00:00 -0500      5  2017
#
#                trait  mean units  cultivar  \
# 51339  canopy_height  91.0    cm  PI329518
# 51340  canopy_height  99.0    cm  PI152828
# 51341  canopy_height  63.0    cm  PI152828
# 75000  canopy_height  22.0    cm  PI619838
# 75001  canopy_height  26.0    cm  PI155885
#
#                                         new_sitename
# 51339   MAC Field Scanner Season 4 Range 30 Column 9
# 51340  MAC Field Scanner Season 4 Range 20 Column 15
# 51341  MAC Field Scanner Season 4 Range 20 Column 15
# 75000  MAC Field Scanner Season 4 Range 35 Column 14
# 75001   MAC Field Scanner Season 4 Range 36 Column 2
