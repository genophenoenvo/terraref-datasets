# %% [markdown]
# ### MAC Season 6 Data Cleaning
# #### Traits
# - aboveground dry biomass
# - canopy height (time series)
#
# #### Season Dates
# - Planting: 2018-04-25
# - Last Day of Harvest: 2018-08-01

# %% [markdown]
# This notebook contains the code Emily Cain used to clean and curate sorghum data from MAC Season 6. The input csv files were queried from betydb version 1 in March 2020 and from the MAC weather station website. To run the entire notebook (in the CyVerse Discovery Environment, for now, where the input data are stored) and output the csv files for the traits above, select `Run` and then `Run All Cells` from the notebook menu above. Once all cells have been executed, the output csv file will appear in the file panel on the left. Right click to download the file. If you experience any problems or have questions, please e-mail ejcain@arizona.edu.

# %% [markdown]
# #### Custom Functions Used

# %%
def check_for_subplots(df):
    
    """
    Function takes a dataframe as argument and checks for sitename subplots ending in ' E' or ' W'
    Will return rows with subplots, if any.
    """
    return df.loc[(df.sitename.str.endswith(' E')) | (df.sitename.str.endswith(' W'))]

# %% [markdown]
# #### I. Import python packages

# %%
import datetime
import numpy as np
import pandas as pd
import sqlalchemy
import sqlite3

# %% [markdown]
# #### II. Read in dataset
# Future: query betydb directly with public API key for most recent data

# %%
df_0 = pd.read_csv('mac_season_six_2020-03-09.csv', low_memory=False)
print(df_0.shape)
df_0.head(3)
# Out:
# (881869, 39)
#    Unnamed: 0  checked result_type            id  citation_id     site_id  \
# 0           1        0      traits  6.002883e+09          NaN  6000014922
# 1           2        0      traits  6.002883e+09          NaN  6000014928
# 2           3        0      traits  6.002883e+09          NaN  6000014929
#
#    treatment_id                                       sitename      city  \
# 0    6000000032  MAC Field Scanner Season 6 Range 12 Column 12  Maricopa
# 1    6000000032  MAC Field Scanner Season 6 Range 12 Column 13  Maricopa
# 2    6000000032  MAC Field Scanner Season 6 Range 12 Column 15  Maricopa
#
#          lat  ...   n statname stat notes  access_level  cultivar entity  \
# 0  33.074943  ... NaN      NaN  NaN   NaN             2  PI656065    NaN
# 1  33.074943  ... NaN      NaN  NaN   NaN             2  PI569422    NaN
# 2  33.074943  ... NaN      NaN  NaN   NaN             2  PI329614    NaN
#
#                              method_name  \
# 0  Mean temperature from infrared images
# 1  Mean temperature from infrared images
# 2  Mean temperature from infrared images
#
#                                             view_url  \
# 0  https://terraref.ncsa.illinois.edu/bety/traits...
# 1  https://terraref.ncsa.illinois.edu/bety/traits...
# 2  https://terraref.ncsa.illinois.edu/bety/traits...
#
#                                             edit_url
# 0  https://terraref.ncsa.illinois.edu/bety/traits...
# 1  https://terraref.ncsa.illinois.edu/bety/traits...
# 2  https://terraref.ncsa.illinois.edu/bety/traits...
#
# [3 rows x 39 columns]

# %% [markdown]
# #### III. Drop Columns

# %%
df_0.columns
# Out:
# Index(['Unnamed: 0', 'checked', 'result_type', 'id', 'citation_id', 'site_id',
#        'treatment_id', 'sitename', 'city', 'lat', 'lon', 'scientificname',
#        'commonname', 'genus', 'species_id', 'cultivar_id', 'author',
#        'citation_year', 'treatment', 'date', 'time', 'raw_date', 'month',
#        'year', 'dateloc', 'trait', 'trait_description', 'mean', 'units', 'n',
#        'statname', 'stat', 'notes', 'access_level', 'cultivar', 'entity',
#        'method_name', 'view_url', 'edit_url'],
#       dtype='object')

# %%
cols_to_drop = ['Unnamed: 0', 'checked', 'result_type', 'id', 'citation_id', 'site_id', 'treatment_id', 'city', 
                'scientificname', 'commonname', 'genus', 'species_id', 'cultivar_id', 'author',
                'citation_year', 'time', 'raw_date', 'month', 'year', 'dateloc', 'n', 'statname', 'stat', 'notes', 
                'access_level', 'entity', 'view_url', 'edit_url']

# %%
df_1 = df_0.drop(labels=cols_to_drop, axis=1)
print(df_1.shape)
df_1.head(3)
# Out:
# (881869, 11)
#                                         sitename        lat         lon  \
# 0  MAC Field Scanner Season 6 Range 12 Column 12  33.074943 -111.974868
# 1  MAC Field Scanner Season 6 Range 12 Column 13  33.074943 -111.974851
# 2  MAC Field Scanner Season 6 Range 12 Column 15  33.074943 -111.974819
#
#                treatment         date                trait  \
# 0  MAC Season 6: Sorghum  2018 Jul 19  surface_temperature
# 1  MAC Season 6: Sorghum  2018 Jul 19  surface_temperature
# 2  MAC Season 6: Sorghum  2018 Jul 19  surface_temperature
#
#      trait_description       mean units  cultivar  \
# 0  Surface temperature  39.207788     C  PI656065
# 1  Surface temperature  39.673700     C  PI569422
# 2  Surface temperature  40.171472     C  PI329614
#
#                              method_name
# 0  Mean temperature from infrared images
# 1  Mean temperature from infrared images
# 2  Mean temperature from infrared images

# %%
for col in df_1.columns:
    print(f'{col}: {df_1[col].nunique()}')
# Out:
# sitename: 2509
# lat: 2509
# lon: 2509
# treatment: 1
# date: 128
# trait: 17
# trait_description: 10
# mean: 304721
# units: 9
# cultivar: 326
# method_name: 14

# %%
# check for drought treatment

df_1.treatment.unique()
# Out:
# array(['MAC Season 6: Sorghum'], dtype=object)

# %% [markdown]
# #### IV. Change `date` format

# %%
new_dates = []

for d in df_1.date.values:
    
    # strip '(America/Phoenix)' string from date
    if 'Phoenix' in d:
        new_name = d[:-18]
        new_dates.append(new_name)
    
    else:
        new_name = d
        new_dates.append(new_name)
        

# check that length of new dates matches number of rows
print(len(new_dates))
print(df_1.shape[0])
# Out:
# 881869
# 881869

# %% [markdown]
# Convert string dates to datetime

# %%
iso_format_dates = pd.to_datetime(new_dates)

# %% [markdown]
# Add new column with datetime values

# %%
# copy df to avoid SettingWithCopyWarning
df_2 = df_1.copy()
df_2['date_1'] = iso_format_dates

print(df_2.shape)
df_2.head(3)
# Out:
# (881869, 12)
#                                         sitename        lat         lon  \
# 0  MAC Field Scanner Season 6 Range 12 Column 12  33.074943 -111.974868
# 1  MAC Field Scanner Season 6 Range 12 Column 13  33.074943 -111.974851
# 2  MAC Field Scanner Season 6 Range 12 Column 15  33.074943 -111.974819
#
#                treatment         date                trait  \
# 0  MAC Season 6: Sorghum  2018 Jul 19  surface_temperature
# 1  MAC Season 6: Sorghum  2018 Jul 19  surface_temperature
# 2  MAC Season 6: Sorghum  2018 Jul 19  surface_temperature
#
#      trait_description       mean units  cultivar  \
# 0  Surface temperature  39.207788     C  PI656065
# 1  Surface temperature  39.673700     C  PI569422
# 2  Surface temperature  40.171472     C  PI329614
#
#                              method_name     date_1
# 0  Mean temperature from infrared images 2018-07-19
# 1  Mean temperature from infrared images 2018-07-19
# 2  Mean temperature from infrared images 2018-07-19

# %% [markdown]
# #### V. Extract Range & Column Values for Location

# %%
df_3 = df_2.copy()

df_3['range'] = df_3['sitename'].str.extract("Range (\d+)").astype(int)
df_3['column'] = df_3['sitename'].str.extract("Column (\d+)").astype(int)

df_3.sample(n=3)
# Out:
#                                               sitename        lat         lon  \
# 643312     MAC Field Scanner Season 6 Range 2 Column 2  33.074584 -111.975031
# 466836  MAC Field Scanner Season 6 Range 40 Column 6 W  33.075949 -111.974970
# 773008    MAC Field Scanner Season 6 Range 46 Column 6  33.076165 -111.974966
#
#                     treatment        date                trait  \
# 643312  MAC Season 6: Sorghum  2018 Jul 8  surface_temperature
# 466836  MAC Season 6: Sorghum  2018 Jul 2  surface_temperature
# 773008  MAC Season 6: Sorghum  2018 Jul 7         canopy_cover
#
#                           trait_description       mean units  cultivar  \
# 643312                  Surface temperature  35.077081     C    SP1516
# 466836                  Surface temperature  31.069391     C   PI63715
# 773008  Fraction of ground covered by plant  84.559625     %  PI152651
#
#                                               method_name     date_1  range  \
# 643312              Mean temperature from infrared images 2018-07-08      2
# 466836              Mean temperature from infrared images 2018-07-02     40
# 773008  Green Canopy Cover Estimation from Field Scann... 2018-07-07     46
#
#         column
# 643312       2
# 466836       6
# 773008       6

# %% [markdown]
# #### VI. Drop, Rename, & Reorder Columns

# %%
# drop string date column

df_4 = df_3.drop(labels=['date'], axis=1)

# %%
df_5 = df_4.rename({'date_1': 'date', 'mean': 'value'}, axis=1)

# %%
new_col_order = ['sitename', 'range', 'column', 'lat', 'lon', 'date', 'treatment', 'trait', 'trait_description', 'method_name', 'cultivar', 'value', 'units']

df_6 = pd.DataFrame(data=df_5, columns=new_col_order).reset_index(drop=True)
print(df_6.shape)
df_6.head(3)
# Out:
# (881869, 13)
#                                         sitename  range  column        lat  \
# 0  MAC Field Scanner Season 6 Range 12 Column 12     12      12  33.074943
# 1  MAC Field Scanner Season 6 Range 12 Column 13     12      13  33.074943
# 2  MAC Field Scanner Season 6 Range 12 Column 15     12      15  33.074943
#
#           lon       date              treatment                trait  \
# 0 -111.974868 2018-07-19  MAC Season 6: Sorghum  surface_temperature
# 1 -111.974851 2018-07-19  MAC Season 6: Sorghum  surface_temperature
# 2 -111.974819 2018-07-19  MAC Season 6: Sorghum  surface_temperature
#
#      trait_description                            method_name  cultivar  \
# 0  Surface temperature  Mean temperature from infrared images  PI656065
# 1  Surface temperature  Mean temperature from infrared images  PI569422
# 2  Surface temperature  Mean temperature from infrared images  PI329614
#
#        value units
# 0  39.207788     C
# 1  39.673700     C
# 2  40.171472     C

# %%
df_6.trait.unique()
# Out:
# array(['surface_temperature', 'canopy_height', 'canopy_cover',
#        'leaf_angle_mean', 'leaf_angle_alpha', 'leaf_angle_beta',
#        'leaf_angle_chi', 'aboveground_biomass_moisture',
#        'aboveground_fresh_biomass', 'leaf_width', 'leaf_length',
#        'aboveground_dry_biomass', 'panicle_count', 'panicle_volume',
#        'panicle_surface_area', 'stalk_diameter_fixed_height',
#        'emergence_count'], dtype=object)

# %% [markdown]
# #### VI. Select for specific traits
# - aboveground dry biomass
# - canopy height - time series

# %% [markdown]
# ### A. Aboveground Dry Biomass

# %%
adb_df = df_6.loc[df_6.trait == 'aboveground_dry_biomass']
print(adb_df.shape)
adb_df.tail(3)
# Out:
# (808, 13)
#                                              sitename  range  column  \
# 849427   MAC Field Scanner Season 6 Range 51 Column 5     51       5
# 849428  MAC Field Scanner Season 6 Range 52 Column 14     52      14
# 849429  MAC Field Scanner Season 6 Range 52 Column 15     52      15
#
#               lat         lon       date              treatment  \
# 849427  33.076345 -111.974983 2018-08-01  MAC Season 6: Sorghum
# 849428  33.076381 -111.974836 2018-08-01  MAC Season 6: Sorghum
# 849429  33.076381 -111.974819 2018-08-01  MAC Season 6: Sorghum
#
#                           trait        trait_description  \
# 849427  aboveground_dry_biomass  Aboveground Dry Biomass
# 849428  aboveground_dry_biomass  Aboveground Dry Biomass
# 849429  aboveground_dry_biomass  Aboveground Dry Biomass
#
#                                   method_name  cultivar    value    units
# 849427  Whole above ground biomass at harvest  PI563022   8270.0  kg / ha
# 849428  Whole above ground biomass at harvest    SP1516  11800.0  kg / ha
# 849429  Whole above ground biomass at harvest    SP1516   6910.0  kg / ha

# %% [markdown]
# ##### Check for E and W subplots

# %%
# will have no output if there are no subplots

check_for_subplots(adb_df)
# Out:
# Empty DataFrame
# Columns: [sitename, range, column, lat, lon, date, treatment, trait, trait_description, method_name, cultivar, value, units]
# Index: []

# %%
# check date ranges - should only include two dates of harvesting

print(adb_df.date.min())
print(adb_df.date.max())
# Out:
# 2018-07-31 00:00:00
# 2018-08-01 00:00:00

# %% [markdown]
# #### Write dataframe to csv file with timestamp

# %%
timestamp = datetime.datetime.now().replace(microsecond=0).isoformat()
output_filename = f'aboveground_dry_biomass_season_6_{timestamp}.csv'.replace(':', '')

adb_df.to_csv(output_filename, index=False)

# %% [markdown]
# ### B. Canopy Height - Time Series

# %%
ch_0 = df_6.loc[df_6.trait == 'canopy_height']
print(ch_0.shape)
ch_0.head(3)
# Out:
# (42271, 13)
#                                             sitename  range  column  \
# 12081  MAC Field Scanner Season 6 Range 23 Column 11     23      11
# 12082   MAC Field Scanner Season 6 Range 9 Column 15      9      15
# 12083    MAC Field Scanner Season 6 Range 5 Column 8      5       8
#
#              lat         lon       date              treatment          trait  \
# 12081  33.075338 -111.974884 2018-06-03  MAC Season 6: Sorghum  canopy_height
# 12082  33.074835 -111.974818 2018-06-13  MAC Season 6: Sorghum  canopy_height
# 12083  33.074691 -111.974933 2018-06-14  MAC Season 6: Sorghum  canopy_height
#
#                                        trait_description  \
# 12081  top of the general canopy of the plant, discou...
# 12082  top of the general canopy of the plant, discou...
# 12083  top of the general canopy of the plant, discou...
#
#                          method_name  cultivar  value units
# 12081  Scanner 3d ply data to height   PI63715  122.0    cm
# 12082  Scanner 3d ply data to height  PI329618  159.0    cm
# 12083  Scanner 3d ply data to height  PI569420  160.0    cm

# %%
subplots = check_for_subplots(ch_0)
subplots.shape
# Out:
# (0, 13)

# %% [markdown]
# #### Check for canopy height values taken on the same day in the same plot

# %%
ch_0.duplicated(subset=['sitename', 'date']).value_counts()
# Out:
# False    30552
# True     11719
# dtype: int64

# %%
duplicates = ch_0.loc[ch_0.duplicated(subset=['sitename', 'date'], keep='first')]
duplicates.head(3)
# Out:
#                                              sitename  range  column  \
# 189107  MAC Field Scanner Season 6 Range 19 Column 15     19      15
# 200325    MAC Field Scanner Season 6 Range 4 Column 6      4       6
# 200344    MAC Field Scanner Season 6 Range 4 Column 7      4       7
#
#               lat         lon       date              treatment  \
# 189107  33.075195 -111.974819 2018-04-19  MAC Season 6: Sorghum
# 200325  33.074655 -111.974966 2018-05-28  MAC Season 6: Sorghum
# 200344  33.074655 -111.974949 2018-05-28  MAC Season 6: Sorghum
#
#                 trait                                  trait_description  \
# 189107  canopy_height  top of the general canopy of the plant, discou...
# 200325  canopy_height  top of the general canopy of the plant, discou...
# 200344  canopy_height  top of the general canopy of the plant, discou...
#
#                                method_name  cultivar  value units
# 189107  3D scanner to 98th quantile height  PI154844   11.0    cm
# 200325       Scanner 3d ply data to height  PI585452   96.0    cm
# 200344       Scanner 3d ply data to height  PI570400   94.0    cm

# %%
# check for hand measurements
duplicates.method_name.unique()
# Out:
# array(['3D scanner to 98th quantile height',
#        'Scanner 3d ply data to height'], dtype=object)

# %%
# check one of the duplicates

duplicates.loc[(duplicates.sitename == 'MAC Field Scanner Season 6 Range 4 Column 7') & (duplicates.date == '2018-05-28')]
# Out:
#                                            sitename  range  column        lat  \
# 200344  MAC Field Scanner Season 6 Range 4 Column 7      4       7  33.074655
# 861116  MAC Field Scanner Season 6 Range 4 Column 7      4       7  33.074655
#
#                lon       date              treatment          trait  \
# 200344 -111.974949 2018-05-28  MAC Season 6: Sorghum  canopy_height
# 861116 -111.974949 2018-05-28  MAC Season 6: Sorghum  canopy_height
#
#                                         trait_description  \
# 200344  top of the general canopy of the plant, discou...
# 861116  top of the general canopy of the plant, discou...
#
#                           method_name  cultivar  value units
# 200344  Scanner 3d ply data to height  PI570400   94.0    cm
# 861116  Scanner 3d ply data to height  PI570400   94.0    cm

# %% [markdown]
# #### Use sqlite database to group by `sitename` and `date`

# %%
conn = sqlite3.connect('canopy_heights_season_6.sqlite')
cursor = conn.cursor()
print("Opened database successfully")
# Out:
# Opened database successfully

# %%
# comment next line out if db has already been created
ch_0.to_sql('canopy_heights_season_6.sqlite', conn)

# %%
ch_1 = pd.read_sql_query("""
                            SELECT sitename, range, column, lat, lon, date, treatment, 
                            trait, trait_description, method_name, cultivar, 
                            ROUND(AVG(value), 2) AS avg_canopy_height, units 
                            FROM 'canopy_heights_season_6.sqlite'
                            GROUP BY sitename, date, cultivar
                            ORDER BY date ASC;
                            """, conn)

print(ch_1.shape)
ch_1.head(3)
# Out:
# (30552, 13)
#                                         sitename  range  column        lat  \
# 0  MAC Field Scanner Season 6 Range 10 Column 11     10      11  33.074871
# 1  MAC Field Scanner Season 6 Range 10 Column 12     10      12  33.074871
# 2  MAC Field Scanner Season 6 Range 10 Column 13     10      13  33.074871
#
#           lon                 date              treatment          trait  \
# 0 -111.974884  2018-04-19 00:00:00  MAC Season 6: Sorghum  canopy_height
# 1 -111.974868  2018-04-19 00:00:00  MAC Season 6: Sorghum  canopy_height
# 2 -111.974851  2018-04-19 00:00:00  MAC Season 6: Sorghum  canopy_height
#
#                                    trait_description  \
# 0  top of the general canopy of the plant, discou...
# 1  top of the general canopy of the plant, discou...
# 2  top of the general canopy of the plant, discou...
#
#                           method_name  cultivar  avg_canopy_height units
# 0  3D scanner to 98th quantile height  PI569419               12.0    cm
# 1  3D scanner to 98th quantile height  PI156330               11.0    cm
# 2  3D scanner to 98th quantile height  PI562998               11.0    cm

# %%
# Sanity Check

sample_with_duplicate = ch_0.loc[(ch_0.range == 4) & (ch_0.column == 6) & (ch_0.date == '2018-05-28')]
sample_with_duplicate
# Out:
#                                            sitename  range  column        lat  \
# 12990   MAC Field Scanner Season 6 Range 4 Column 6      4       6  33.074655
# 200325  MAC Field Scanner Season 6 Range 4 Column 6      4       6  33.074655
# 861097  MAC Field Scanner Season 6 Range 4 Column 6      4       6  33.074655
#
#                lon       date              treatment          trait  \
# 12990  -111.974966 2018-05-28  MAC Season 6: Sorghum  canopy_height
# 200325 -111.974966 2018-05-28  MAC Season 6: Sorghum  canopy_height
# 861097 -111.974966 2018-05-28  MAC Season 6: Sorghum  canopy_height
#
#                                         trait_description  \
# 12990   top of the general canopy of the plant, discou...
# 200325  top of the general canopy of the plant, discou...
# 861097  top of the general canopy of the plant, discou...
#
#                           method_name  cultivar  value units
# 12990   Scanner 3d ply data to height  PI585452   96.0    cm
# 200325  Scanner 3d ply data to height  PI585452   96.0    cm
# 861097  Scanner 3d ply data to height  PI585452   96.0    cm

# %%
# Sanity Check - should have only one row for the above group

sample_without_duplicate = ch_1.loc[(ch_1.range == 4) & (ch_1.column == 6) & (ch_1.date == '2018-05-28 00:00:00')]
sample_without_duplicate
# Out:
#                                           sitename  range  column        lat  \
# 13420  MAC Field Scanner Season 6 Range 4 Column 6      4       6  33.074655
#
#               lon                 date              treatment          trait  \
# 13420 -111.974966  2018-05-28 00:00:00  MAC Season 6: Sorghum  canopy_height
#
#                                        trait_description  \
# 13420  top of the general canopy of the plant, discou...
#
#                          method_name  cultivar  avg_canopy_height units
# 13420  Scanner 3d ply data to height  PI585452               96.0    cm

# %% [markdown]
# #### Write dataframe to csv file with timestamp

# %%
timestamp = datetime.datetime.now().replace(microsecond=0).isoformat()
output_filename = f'canopy_height_time_series_season_6_{timestamp}.csv'.replace(':', '')

ch_1.to_csv(output_filename, index=False)

# %% [markdown]
# #### C. Growing Degree Days / Weather Data for Season Six
# No `days_to_flowering` or `days_to_flag_leaf_emergence` for season 6, but will add GDD values for season in case needed for other traits

# %% [markdown]
# #### Read in Season Six Weather Data from MAC Weather Station

# %%
weather_df_0 = pd.read_csv('mac_weather_station_raw_daily_2018.csv')
print(weather_df_0.shape)
weather_df_0.head(3)
# Out:
# (365, 28)
#    year  day_of_year  station_num  air_temp_max  air_temp_min  air_temp_mean  \
# 0  2018            1            6          23.6           0.4           10.4
# 1  2018            2            6          23.0           3.6           11.6
# 2  2018            3            6          24.2           1.8           12.9
#
#    rh_max  rh_min  rh_mean  vpd_mean  ...  wind_speed_mean  wind_vec_mag  \
# 0    75.9    11.7     41.5      0.94  ...              0.9           0.1
# 1    70.4    11.7     37.7      1.01  ...              0.8           0.3
# 2    73.9    11.8     35.7      1.17  ...              2.0           1.2
#
#    wind_vec_dir  wind_dir_std  max_wind_speed  heat_units  eto  eto_pm  \
# 0           159            74             3.8         3.4  2.3     1.8
# 1           302            67             3.8         3.4  2.5     1.7
# 2            50            50             8.1         3.7  2.8     3.1
#
#    vapor_pressure_mean  dewpoint_mean
# 0                 0.46           -4.0
# 1                 0.47           -3.7
# 2                 0.47           -3.6
#
# [3 rows x 28 columns]

# %% [markdown]
# #### Slice dataframe for season dates only and add date column
# * Planting Date: 2018-04-25, Day 115
# * Last Day of Harvest: 2018-08-01, Day 213

# %%
weather_df_1 = weather_df_0.loc[(weather_df_0.day_of_year >= 115) & (weather_df_0.day_of_year <= 213)]
print(weather_df_1.shape)
weather_df_1.head(3)
# Out:
# (99, 28)
#      year  day_of_year  station_num  air_temp_max  air_temp_min  \
# 114  2018          115            6          36.6          17.1
# 115  2018          116            6          34.5          18.2
# 116  2018          117            6          36.4          17.6
#
#      air_temp_mean  rh_max  rh_min  rh_mean  vpd_mean  ...  wind_speed_mean  \
# 114           27.2    31.0     6.5     16.8      3.26  ...              1.6
# 115           26.8    33.3     9.9     18.7      3.04  ...              2.4
# 116           28.6    48.7     9.6     20.5      3.35  ...              2.0
#
#      wind_vec_mag  wind_vec_dir  wind_dir_std  max_wind_speed  heat_units  \
# 114           0.8           185            57             5.6        12.4
# 115           1.3           208            53             5.9        12.6
# 116           0.9           215            59             7.2        12.6
#
#      eto  eto_pm  vapor_pressure_mean  dewpoint_mean
# 114  7.7     6.7                 0.56           -1.4
# 115  6.1     6.7                 0.63            0.3
# 116  7.9     7.1                 0.74            2.5
#
# [3 rows x 28 columns]

# %%
season_4_date_range = pd.date_range(start='2018-04-25', end='2018-08-01')

# %%
weather_df_2 = weather_df_1.copy()
weather_df_2['date'] = season_4_date_range
print(weather_df_2.shape)
weather_df_2.tail(3)
# Out:
# (99, 29)
#      year  day_of_year  station_num  air_temp_max  air_temp_min  \
# 210  2018          211            6          41.9          27.2
# 211  2018          212            6          40.9          26.0
# 212  2018          213            6          42.9          28.9
#
#      air_temp_mean  rh_max  rh_min  rh_mean  vpd_mean  ...  wind_vec_mag  \
# 210           34.2    64.9    22.3     41.4      3.44  ...           1.0
# 211           33.7    79.8    18.8     42.1      3.35  ...           0.6
# 212           36.0    64.7    14.9     36.3      4.05  ...           1.5
#
#      wind_vec_dir  wind_dir_std  max_wind_speed  heat_units  eto  eto_pm  \
# 210           215            66            12.5        16.7  8.7     9.1
# 211           154            65             8.4        16.3  7.6     7.4
# 212           154            52            14.7        17.1  8.6     8.9
#
#      vapor_pressure_mean  dewpoint_mean       date
# 210                 2.12           18.3 2018-07-30
# 211                 2.03           17.6 2018-07-31
# 212                 2.02           17.4 2018-08-01
#
# [3 rows x 29 columns]

# %% [markdown]
# #### Add Growing Degree Days
# - Future: add LaTeX equation
# - Future: add info about min and max daily values
# - 10 degrees Celsius is base temp for sorghum
# - Daily gdd value = ((max temp + min temp) / 2) - 10 (base temp)
# - Growing Degree Days = cumulative sum of daily gdd values

# %%
weather_df_3 = weather_df_2.copy()
weather_df_3['daily_gdd'] = (((weather_df_3['air_temp_max'] + weather_df_3['air_temp_min'])) / 2) - 10
print(weather_df_3.shape)
weather_df_3.head(3)
# Out:
# (99, 30)
#      year  day_of_year  station_num  air_temp_max  air_temp_min  \
# 114  2018          115            6          36.6          17.1
# 115  2018          116            6          34.5          18.2
# 116  2018          117            6          36.4          17.6
#
#      air_temp_mean  rh_max  rh_min  rh_mean  vpd_mean  ...  wind_vec_dir  \
# 114           27.2    31.0     6.5     16.8      3.26  ...           185
# 115           26.8    33.3     9.9     18.7      3.04  ...           208
# 116           28.6    48.7     9.6     20.5      3.35  ...           215
#
#      wind_dir_std  max_wind_speed  heat_units  eto  eto_pm  \
# 114            57             5.6        12.4  7.7     6.7
# 115            53             5.9        12.6  6.1     6.7
# 116            59             7.2        12.6  7.9     7.1
#
#      vapor_pressure_mean  dewpoint_mean       date  daily_gdd
# 114                 0.56           -1.4 2018-04-25      16.85
# 115                 0.63            0.3 2018-04-26      16.35
# 116                 0.74            2.5 2018-04-27      17.00
#
# [3 rows x 30 columns]

# %%
weather_df_4 = weather_df_3.copy()

# round to the nearest integer
weather_df_4['gdd'] = np.rint(np.cumsum(weather_df_4['daily_gdd']))
print(weather_df_4.shape)
weather_df_4.tail(3)
# Out:
# (99, 31)
#      year  day_of_year  station_num  air_temp_max  air_temp_min  \
# 210  2018          211            6          41.9          27.2
# 211  2018          212            6          40.9          26.0
# 212  2018          213            6          42.9          28.9
#
#      air_temp_mean  rh_max  rh_min  rh_mean  vpd_mean  ...  wind_dir_std  \
# 210           34.2    64.9    22.3     41.4      3.44  ...            66
# 211           33.7    79.8    18.8     42.1      3.35  ...            65
# 212           36.0    64.7    14.9     36.3      4.05  ...            52
#
#      max_wind_speed  heat_units  eto  eto_pm  vapor_pressure_mean  \
# 210            12.5        16.7  8.7     9.1                 2.12
# 211             8.4        16.3  7.6     7.4                 2.03
# 212            14.7        17.1  8.6     8.9                 2.02
#
#      dewpoint_mean       date  daily_gdd     gdd
# 210           18.3 2018-07-30      24.55  1923.0
# 211           17.6 2018-07-31      23.45  1947.0
# 212           17.4 2018-08-01      25.90  1973.0
#
# [3 rows x 31 columns]

# %% [markdown]
# #### Drop `daily_gdd` and reorder columns

# %%
day_of_planting = datetime.date(2017,4,20)
fle_1 = fle_0.copy()

fle_1['date_of_planting'] = day_of_planting
print(fle_1.shape)
fle_1.head(3)

# %% [markdown]
# #### Create timedelta using days to flag leaf emergence

# %%
timedelta_values = fle_1['value'].values
dates_of_flag_leaf_emergence = []

for val in timedelta_values:
    
    date_of_flag_leaf_emergence = day_of_planting + datetime.timedelta(days=val)
    dates_of_flag_leaf_emergence.append(date_of_flag_leaf_emergence)
    
print(fle_1.shape[0])
print(len(dates_of_flag_leaf_emergence))

# %%
fle_2 = fle_1.copy()
fle_2['date_of_flag_leaf_emergence'] = dates_of_flag_leaf_emergence
print(fle_2.shape)
fle_2.head(3)

# %% [markdown]
# #### Add GDD to flag leaf emergence

# %%
# slice df for date and cumulative gdd values only

season_4_gdd = weather_df_4[['date', 'gdd']]
print(season_4_gdd.shape)
season_4_gdd.head(3)

# %%
fle_2.dtypes

# %%
fle_3 = fle_2.copy()
fle_3.date_of_flag_leaf_emergence = pd.to_datetime(fle_3.date_of_flag_leaf_emergence)
fle_3.dtypes

# %%
fle_4 = fle_3.merge(season_4_gdd, how='left', left_on='date_of_flag_leaf_emergence', right_on='date')
print(fle_4.shape)
fle_4.head(3)

# %% [markdown]
# #### Drop all date columns except `date_of_flag_leaf_emergence`

# %%
date_cols_to_drop = ['date_x', 'date_of_planting', 'date_y']
fle_5 = fle_4.drop(labels=date_cols_to_drop, axis=1)
print(fle_5.shape)
fle_5.tail(3)

# %% [markdown]
# #### Check for duplicates

# %%
fle_5.duplicated().value_counts()

# %%
# keep duplicates for now?

# %% [markdown]
# #### Write dataframe to csv file with timestamp

# %%
timestamp = datetime.datetime.now().replace(microsecond=0).isoformat()
output_filename = f'days_gdd_to_flag_leaf_emergence_season_4_{timestamp}.csv'.replace(':', '')

fle_5.to_csv(output_filename, index=False)
