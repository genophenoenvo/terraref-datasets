# %% [markdown]
# ## Weather Station Data Season 6
#
# ### MAC Weather Station
# * 2018 raw [data](https://cals.arizona.edu/azmet/06.htm)

# %%
import datetime
import numpy as np
import pandas as pd

# %%
df_0 = pd.read_csv('data/raw/weather_station_2018_daily.csv')
# df_0.head()
# Out:
#    year  day_of_year  station_num  air_temp_max  air_temp_min  air_temp_mean  \
# 0  2018            1            6          23.6           0.4           10.4
# 1  2018            2            6          23.0           3.6           11.6
# 2  2018            3            6          24.2           1.8           12.9
# 3  2018            4            6          25.5           9.6           16.6
# 4  2018            5            6          24.6           3.4           12.9
#
#    rh_max  rh_min  rh_mean  vpd_mean  ...  wind_speed_mean  wind_vec_mag  \
# 0    75.9    11.7     41.5      0.94  ...              0.9           0.1
# 1    70.4    11.7     37.7      1.01  ...              0.8           0.3
# 2    73.9    11.8     35.7      1.17  ...              2.0           1.2
# 3    52.6    15.9     30.8      1.41  ...              1.0           0.2
# 4    76.6    21.0     46.4      0.96  ...              0.8           0.1
#
#    wind_vec_dir  wind_dir_std  max_wind_speed  heat_units  eto  eto_pm  \
# 0           159            74             3.8         3.4  2.3     1.8
# 1           302            67             3.8         3.4  2.5     1.7
# 2            50            50             8.1         3.7  2.8     3.1
# 3           108            72             4.2         5.4  3.0     2.1
# 4           126            75             3.3         4.0  2.5     1.8
#
#    vapor_pressure_mean  dewpoint_mean
# 0                 0.46           -4.0
# 1                 0.47           -3.7
# 2                 0.47           -3.6
# 3                 0.57           -1.2
# 4                 0.64            0.7
#
# [5 rows x 28 columns]

# %%
df_0.shape
# Out:
# (365, 28)

# %% [markdown]
# ### I. Drop columns not needed at this time

# %%
df_0.columns
# Out:
# Index(['year', 'day_of_year', 'station_num', 'air_temp_max', 'air_temp_min',
#        'air_temp_mean', 'rh_max', 'rh_min', 'rh_mean', 'vpd_mean',
#        'solar_rad_total', 'precip_total', 'four_in_soil_temp_max',
#        'four_in_soil_temp_min', 'four_in_soil_temp_mean',
#        'twenty_in_soil_temp_max', 'four_in_soil_temp_min.1',
#        'four_in_soil_temp_mean.1', 'wind_speed_mean', 'wind_vec_mag',
#        'wind_vec_dir', 'wind_dir_std', 'max_wind_speed', 'heat_units', 'eto',
#        'eto_pm', 'vapor_pressure_mean', 'dewpoint_mean'],
#       dtype='object')

# %%
cols_to_drop = ['year', 'station_num', 'vpd_mean', 'solar_rad_total', 'four_in_soil_temp_max', 'four_in_soil_temp_min',
                'four_in_soil_temp_mean', 'twenty_in_soil_temp_max', 'four_in_soil_temp_min.1', 'four_in_soil_temp_mean.1',
                'heat_units', 'eto','eto_pm', 'vapor_pressure_mean', 'dewpoint_mean']

# %%
df_1 = df_0.drop(labels=cols_to_drop, axis=1)
# df_1.head()
# Out:
#    day_of_year  air_temp_max  air_temp_min  air_temp_mean  rh_max  rh_min  \
# 0            1          23.6           0.4           10.4    75.9    11.7
# 1            2          23.0           3.6           11.6    70.4    11.7
# 2            3          24.2           1.8           12.9    73.9    11.8
# 3            4          25.5           9.6           16.6    52.6    15.9
# 4            5          24.6           3.4           12.9    76.6    21.0
#
#    rh_mean  precip_total  wind_speed_mean  wind_vec_mag  wind_vec_dir  \
# 0     41.5           0.0              0.9           0.1           159
# 1     37.7           0.0              0.8           0.3           302
# 2     35.7           0.0              2.0           1.2            50
# 3     30.8           0.0              1.0           0.2           108
# 4     46.4           0.0              0.8           0.1           126
#
#    wind_dir_std  max_wind_speed
# 0            74             3.8
# 1            67             3.8
# 2            50             8.1
# 3            72             4.2
# 4            75             3.3

# %% [markdown]
# ### II. Slice dataframe for season dates only and add date column
# * Planting Date: 2018-04-25, Day 115
# * Last Day of Harvest: 2018-08-01, Day 213

# %%
df_2 = df_1.loc[(df_1.day_of_year >= 115) & (df_1.day_of_year <= 213)]
df_2.shape
# Out:
# (99, 13)

# %%
season_5_date_range = pd.date_range(start='2018-04-25', end='2018-08-01')

# %%
df_3 = df_2.copy()
df_3['date'] = season_5_date_range
# df_3.head()
# Out:
#      day_of_year  air_temp_max  air_temp_min  air_temp_mean  rh_max  rh_min  \
# 114          115          36.6          17.1           27.2    31.0     6.5
# 115          116          34.5          18.2           26.8    33.3     9.9
# 116          117          36.4          17.6           28.6    48.7     9.6
# 117          118          35.9          19.1           28.1    41.0     8.3
# 118          119          33.8          15.6           24.8    44.3     7.3
#
#      rh_mean  precip_total  wind_speed_mean  wind_vec_mag  wind_vec_dir  \
# 114     16.8           0.0              1.6           0.8           185
# 115     18.7           0.0              2.4           1.3           208
# 116     20.5           0.0              2.0           0.9           215
# 117     17.8           0.0              2.6           1.7           234
# 118     18.9           0.0              3.1           2.2           201
#
#      wind_dir_std  max_wind_speed       date
# 114            57             5.6 2018-04-25
# 115            53             5.9 2018-04-26
# 116            59             7.2 2018-04-27
# 117            48             8.1 2018-04-28
# 118            44            11.1 2018-04-29

# %% [markdown]
# ### III. Add Growing Degree Days (gdd)

# %%
df_4 = df_3.copy()
df_4['gdd'] = np.rint(np.cumsum((((df_4['air_temp_max'] + df_4['air_temp_min']) / 2) - 10)))
# df_4.head()
# Out:
#      day_of_year  air_temp_max  air_temp_min  air_temp_mean  rh_max  rh_min  \
# 114          115          36.6          17.1           27.2    31.0     6.5
# 115          116          34.5          18.2           26.8    33.3     9.9
# 116          117          36.4          17.6           28.6    48.7     9.6
# 117          118          35.9          19.1           28.1    41.0     8.3
# 118          119          33.8          15.6           24.8    44.3     7.3
#
#      rh_mean  precip_total  wind_speed_mean  wind_vec_mag  wind_vec_dir  \
# 114     16.8           0.0              1.6           0.8           185
# 115     18.7           0.0              2.4           1.3           208
# 116     20.5           0.0              2.0           0.9           215
# 117     17.8           0.0              2.6           1.7           234
# 118     18.9           0.0              3.1           2.2           201
#
#      wind_dir_std  max_wind_speed       date   gdd
# 114            57             5.6 2018-04-25  17.0
# 115            53             5.9 2018-04-26  33.0
# 116            59             7.2 2018-04-27  50.0
# 117            48             8.1 2018-04-28  68.0
# 118            44            11.1 2018-04-29  82.0

# %% [markdown]
# ### IV. Add cumulative precipitation

# %%
df_5 = df_4.copy()
df_5['cum_precip'] = round(np.cumsum(df_5.precip_total), 2)
# df_5.tail()
# Out:
#      day_of_year  air_temp_max  air_temp_min  air_temp_mean  rh_max  rh_min  \
# 208          209          41.6          28.5           34.8    64.4    22.1
# 209          210          38.2          25.6           31.8    85.2    26.5
# 210          211          41.9          27.2           34.2    64.9    22.3
# 211          212          40.9          26.0           33.7    79.8    18.8
# 212          213          42.9          28.9           36.0    64.7    14.9
#
#      rh_mean  precip_total  wind_speed_mean  wind_vec_mag  wind_vec_dir  \
# 208     37.2           0.0              2.7           1.4           178
# 209     50.6           0.0              3.0           1.8           197
# 210     41.4           0.0              3.1           1.0           215
# 211     42.1           0.0              1.8           0.6           154
# 212     36.3           0.0              2.6           1.5           154
#
#      wind_dir_std  max_wind_speed       date     gdd  cum_precip
# 208            57            10.5 2018-07-28  1877.0        5.08
# 209            51            10.8 2018-07-29  1899.0        5.08
# 210            66            12.5 2018-07-30  1923.0        5.08
# 211            65             8.4 2018-07-31  1947.0        5.08
# 212            52            14.7 2018-08-01  1973.0        5.08

# %% [markdown]
# ### V. Set date as index

# %%
df_6 = df_5.set_index(keys='date')
# df_6.head()
# Out:
#             day_of_year  air_temp_max  air_temp_min  air_temp_mean  rh_max  \
# date
# 2018-04-25          115          36.6          17.1           27.2    31.0
# 2018-04-26          116          34.5          18.2           26.8    33.3
# 2018-04-27          117          36.4          17.6           28.6    48.7
# 2018-04-28          118          35.9          19.1           28.1    41.0
# 2018-04-29          119          33.8          15.6           24.8    44.3
#
#             rh_min  rh_mean  precip_total  wind_speed_mean  wind_vec_mag  \
# date
# 2018-04-25     6.5     16.8           0.0              1.6           0.8
# 2018-04-26     9.9     18.7           0.0              2.4           1.3
# 2018-04-27     9.6     20.5           0.0              2.0           0.9
# 2018-04-28     8.3     17.8           0.0              2.6           1.7
# 2018-04-29     7.3     18.9           0.0              3.1           2.2
#
#             wind_vec_dir  wind_dir_std  max_wind_speed   gdd  cum_precip
# date
# 2018-04-25           185            57             5.6  17.0         0.0
# 2018-04-26           208            53             5.9  33.0         0.0
# 2018-04-27           215            59             7.2  50.0         0.0
# 2018-04-28           234            48             8.1  68.0         0.0
# 2018-04-29           201            44            11.1  82.0         0.0

# %% [markdown]
# ### Convert to `.csv`

# %%
need_to_create_csv = True

if need_to_create_csv:

    timestamp = datetime.datetime.now().replace(microsecond=0).isoformat()
    output_filename = f'weather_station_season_6_{timestamp}.csv'.replace(':', '')
    df_6.to_csv(f'data/processed/{output_filename}')
