# %% [markdown]
# ## Season 4 Weather Data
# * queried from geostreams using this [tutorial](https://terraref.github.io/tutorials/accessing-weather-data-in-r.html)
# * date already in AZ / MST time

# %%
import datetime
import numpy as np
import pandas as pd

# %%
weather_df_0 = pd.read_csv('data/raw/season_4_weather_data.csv')
weather_df_0.head()
# Out:
#                                               source  wind_speed  \
# 0  https://terraref.ncsa.illinois.edu/clowder/dat...    1.843458
# 1  https://terraref.ncsa.illinois.edu/clowder/dat...    1.508267
# 2  https://terraref.ncsa.illinois.edu/clowder/dat...    1.827400
# 3  https://terraref.ncsa.illinois.edu/clowder/dat...    2.347067
# 4  https://terraref.ncsa.illinois.edu/clowder/dat...    2.917095
#
#                 source_file  eastward_wind  northward_wind  air_temperature  \
# 0  58f9e4ea4f0ce95015666e02       0.898601        1.151159       303.100327
# 1  58f9e4ea4f0ce95015666e02       0.883875       -0.047253       303.116300
# 2  58f9e4ea4f0ce95015666e02      -1.456812       -0.571688       303.582367
# 3  58f9e4ea4f0ce95015666e02      -1.178588        1.262081       303.520633
# 4  58f9e4ea4f0ce95015666e02      -0.221016        2.690058       303.678953
#
#    relative_humidity  precipitation_rate  \
# 0          19.947991                 0.0
# 1          19.937100                 0.0
# 2          19.490567                 0.0
# 3          18.043000                 0.0
# 4          17.383784                 0.0
#
#    surface_downwelling_shortwave_flux_in_air  \
# 0                                 675.676636
# 1                                 678.462333
# 2                                 683.131000
# 3                                 680.437000
# 4                                 680.580068
#
#    surface_downwelling_photosynthetic_photon_flux_in_air                 time
# 0                                        1813.429907      2017-04-19 12:10:00
# 1                                        1816.936667      2017-04-19 12:15:00
# 2                                        1823.636667      2017-04-19 12:20:00
# 3                                        1821.410000      2017-04-19 12:25:00
# 4                                        1821.422297      2017-04-19 12:30:00

# %%
weather_df_0.columns
# Out:
# Index(['source', 'wind_speed', 'source_file', 'eastward_wind',
#        'northward_wind', 'air_temperature', 'relative_humidity',
#        'precipitation_rate', 'surface_downwelling_shortwave_flux_in_air',
#        'surface_downwelling_photosynthetic_photon_flux_in_air', 'time'],
#       dtype='object')

# %%
weather_df_0.shape
# Out:
# (4453, 11)

# %% [markdown]
# #### I. Drop and reorder columns
# * will drop `surface_downwelling` columns for now until I get more feedback

# %%
new_col_order = ['time', 'air_temperature', 'relative_humidity', 'precipitation_rate', 'eastward_wind', 'northward_wind']

# %%
weather_df_1 = pd.DataFrame(data=weather_df_0, index=weather_df_0.index, columns=new_col_order)
# weather_df_1.head()
# Out:
#                   time  air_temperature  relative_humidity  \
# 0  2017-04-19 12:10:00       303.100327          19.947991
# 1  2017-04-19 12:15:00       303.116300          19.937100
# 2  2017-04-19 12:20:00       303.582367          19.490567
# 3  2017-04-19 12:25:00       303.520633          18.043000
# 4  2017-04-19 12:30:00       303.678953          17.383784
#
#    precipitation_rate  eastward_wind  northward_wind
# 0                 0.0       0.898601        1.151159
# 1                 0.0       0.883875       -0.047253
# 2                 0.0      -1.456812       -0.571688
# 3                 0.0      -1.178588        1.262081
# 4                 0.0      -0.221016        2.690058

# %%
# weather_df_1.tail()
# Out:
#                      time  air_temperature  relative_humidity  \
# 4448  2017-09-14 23:45:00       299.596367          28.869333
# 4449  2017-09-14 23:50:00       299.397567          31.006167
# 4450  2017-09-14 23:55:00       298.822633          36.486500
# 4451  2017-09-15 00:00:00       298.543967          37.805967
# 4452  2017-09-14 15:47:36       304.386970          34.028550
#
#       precipitation_rate  eastward_wind  northward_wind
# 4448                 0.0      -1.137041       -1.255996
# 4449                 0.0       0.694553       -0.882575
# 4450                 0.0       1.831515       -0.457969
# 4451                 0.0       1.731793       -0.628593
# 4452                 0.0      -1.465922       -2.947309

# %% [markdown]
# #### II. Add `date` column with no time values

# %%
time_values = weather_df_1.time.values
just_dates = []

for t in time_values:
    
    just_date = t[:10]
    just_dates.append(just_date)

# print(weather_df_1.shape[0])
# print(len(time_values))
# print(len(just_dates))
# Out:
# 4453
# 4453
# 4453

# %%
weather_df_1['date'] = just_dates
# weather_df_1.tail()
# Out:
#                      time  air_temperature  relative_humidity  \
# 4448  2017-09-14 23:45:00       299.596367          28.869333
# 4449  2017-09-14 23:50:00       299.397567          31.006167
# 4450  2017-09-14 23:55:00       298.822633          36.486500
# 4451  2017-09-15 00:00:00       298.543967          37.805967
# 4452  2017-09-14 15:47:36       304.386970          34.028550
#
#       precipitation_rate  eastward_wind  northward_wind        date
# 4448                 0.0      -1.137041       -1.255996  2017-09-14
# 4449                 0.0       0.694553       -0.882575  2017-09-14
# 4450                 0.0       1.831515       -0.457969  2017-09-14
# 4451                 0.0       1.731793       -0.628593  2017-09-15
# 4452                 0.0      -1.465922       -2.947309  2017-09-14

# %% [markdown]
# #### II. Convert temperature to Celsius
# * can round to nearest int (or not round at all) as needed

# %%
weather_df_2 = weather_df_1.copy()

# %%
weather_df_2['air_temp_C'] = round((weather_df_2['air_temperature'] - 273.15), 2)
# weather_df_2.head()
# Out:
#                   time  air_temperature  relative_humidity  \
# 0  2017-04-19 12:10:00       303.100327          19.947991
# 1  2017-04-19 12:15:00       303.116300          19.937100
# 2  2017-04-19 12:20:00       303.582367          19.490567
# 3  2017-04-19 12:25:00       303.520633          18.043000
# 4  2017-04-19 12:30:00       303.678953          17.383784
#
#    precipitation_rate  eastward_wind  northward_wind        date  air_temp_C
# 0                 0.0       0.898601        1.151159  2017-04-19       29.95
# 1                 0.0       0.883875       -0.047253  2017-04-19       29.97
# 2                 0.0      -1.456812       -0.571688  2017-04-19       30.43
# 3                 0.0      -1.178588        1.262081  2017-04-19       30.37
# 4                 0.0      -0.221016        2.690058  2017-04-19       30.53

# %% [markdown]
# #### III. Add max, min, and mean values
# * Temperature: Drop Kelvin column
# * Relative humidity
# * Precipitation rate

# %%
weather_df_3 = weather_df_2.drop(labels='air_temperature', axis=1)
# weather_df_3.tail()
# Out:
#                      time  relative_humidity  precipitation_rate  \
# 4448  2017-09-14 23:45:00          28.869333                 0.0
# 4449  2017-09-14 23:50:00          31.006167                 0.0
# 4450  2017-09-14 23:55:00          36.486500                 0.0
# 4451  2017-09-15 00:00:00          37.805967                 0.0
# 4452  2017-09-14 15:47:36          34.028550                 0.0
#
#       eastward_wind  northward_wind        date  air_temp_C
# 4448      -1.137041       -1.255996  2017-09-14       26.45
# 4449       0.694553       -0.882575  2017-09-14       26.25
# 4450       1.831515       -0.457969  2017-09-14       25.67
# 4451       1.731793       -0.628593  2017-09-15       25.39
# 4452      -1.465922       -2.947309  2017-09-14       31.24

# %%
# weather_df_3.loc[weather_df_3.date == '2017-04-19']['air_temp_C'].min()
# Out:
# 19.78

# %% [markdown]
# Air temperatures

# %%
min_temp = weather_df_3.groupby('date')['air_temp_C'].min()
max_temp = weather_df_3.groupby('date')['air_temp_C'].max()
mean_temp = weather_df_3.groupby('date')['air_temp_C'].mean()

# %% [markdown]
# Relative humidity

# %%
min_relative_humidity = weather_df_3.groupby('date')['relative_humidity'].min()
max_relative_humidity = weather_df_3.groupby('date')['relative_humidity'].max()
mean_relative_humidity = weather_df_3.groupby('date')['relative_humidity'].mean()

# %% [markdown]
# Precipitation rate

# %%
min_precip_rate = weather_df_3.groupby('date')['precipitation_rate'].min()
max_precip_rate = weather_df_3.groupby('date')['precipitation_rate'].max()
mean_precip_rate = weather_df_3.groupby('date')['precipitation_rate'].mean()

# %%
daily_weather_values = pd.DataFrame({'min_temp': min_temp, 'max_temp': max_temp, 'mean_temp': mean_temp,
                                    'min_relative_humidity': min_relative_humidity, 'max_relative_humidity': max_relative_humidity,
                                    'mean_relative_humidity': mean_relative_humidity, 'min_precip_rate': min_precip_rate,
                                    'max_precip_rate': max_precip_rate, 'mean_precip_rate': mean_precip_rate})
# daily_weather_values.head()
# Out:
#             min_temp  max_temp  mean_temp  min_relative_humidity  \
# date
# 2017-04-19     19.78     31.93  25.448732               7.732900
# 2017-04-20     15.28     33.41  25.046047               4.179077
# 2017-04-21     18.67     19.41  18.985000              17.229600
# 2017-04-23     21.33     37.66  30.450351               5.650270
# 2017-04-24     20.27     31.16  26.177907               8.464933
#
#             max_relative_humidity  mean_relative_humidity  min_precip_rate  \
# date
# 2017-04-19              24.571511               15.610601              0.0
# 2017-04-20              29.937330               14.417725              0.0
# 2017-04-21              19.390400               18.265567              0.0
# 2017-04-23              23.421600               12.054445              0.0
# 2017-04-24              27.061567               17.231600              0.0
#
#             max_precip_rate  mean_precip_rate
# date
# 2017-04-19              0.0               0.0
# 2017-04-20              0.0               0.0
# 2017-04-21              0.0               0.0
# 2017-04-23              0.0               0.0
# 2017-04-24              0.0               0.0

# %%
daily_weather_values_1 = daily_weather_values.sort_index()
# daily_weather_values_1.tail()
# Out:
#             min_temp  max_temp  mean_temp  min_relative_humidity  \
# date
# 2017-09-11     26.37     37.83  31.678209              21.921784
# 2017-09-12     30.62     31.50  31.170000              31.095500
# 2017-09-13     27.91     40.98  32.343333              15.874467
# 2017-09-14     25.62     36.80  28.997241              22.006450
# 2017-09-15     25.39     25.39  25.390000              37.805967
#
#             max_relative_humidity  mean_relative_humidity  min_precip_rate  \
# date
# 2017-09-11              46.254773               32.657997              0.0
# 2017-09-12              33.271467               31.778879              0.0
# 2017-09-13              47.938767               35.913253              0.0
# 2017-09-14              44.430333               32.921517              0.0
# 2017-09-15              37.805967               37.805967              0.0
#
#             max_precip_rate  mean_precip_rate
# date
# 2017-09-11              0.0               0.0
# 2017-09-12              0.0               0.0
# 2017-09-13              0.0               0.0
# 2017-09-14              0.0               0.0
# 2017-09-15              0.0               0.0

# %% [markdown]
# ###

# %% [markdown]
# ### Final Steps

# %%
need_to_create_csv = True

if need_to_create_csv:

    timestamp = datetime.datetime.now().replace(microsecond=0).isoformat()
    output_filename = f'daily_weather_values_{timestamp}.csv'.replace(':', '')
    daily_weather_values_1.to_csv(f'data/processed/{output_filename}')
