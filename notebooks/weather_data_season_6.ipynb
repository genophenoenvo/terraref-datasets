# %% [markdown]
# ## Season 6 Weather Data
# * queried from geostreams using this [tutorial](https://terraref.github.io/tutorials/accessing-weather-data-in-r.html)
# * date already in AZ / MST time
#
# #### Notes
# * missing dates
# * dates with some but not all variable values

# %%
import datetime
import numpy as np
import pandas as pd

# %%
weather_df_0 = pd.read_csv('data/raw/season_6_weather_data.csv')
weather_df_0.head()
# Out:
#                                               source  wind_speed  \
# 0  https://terraref.ncsa.illinois.edu/clowder/dat...    0.656267
# 1  https://terraref.ncsa.illinois.edu/clowder/dat...    1.389333
# 2  https://terraref.ncsa.illinois.edu/clowder/dat...    0.977123
# 3  https://terraref.ncsa.illinois.edu/clowder/dat...    1.233767
# 4  https://terraref.ncsa.illinois.edu/clowder/dat...    1.390433
#
#                 source_file  eastward_wind  northward_wind  air_temperature  \
# 0  5ae3dfa74f0c467c1670a0e1       0.599756       -0.233053       290.105233
# 1  5ae3dfa74f0c467c1670a0e1       1.329997       -0.316545       289.968000
# 2  5ae3dfa74f0c467c1670a0ee      -0.409435        0.435499       290.044447
# 3  5ae3dfa74f0c467c1670a0ee       0.064580       -1.225979       289.220977
# 4  5ae3dfa74f0c467c1670a0ee       0.068203       -1.376049       288.693800
#
#    relative_humidity  precipitation_rate  \
# 0          14.690333                 0.0
# 1          15.773800                 0.0
# 2          18.701601                 0.0
# 3          20.263907                 0.0
# 4          21.982733                 0.0
#
#    surface_downwelling_shortwave_flux_in_air  \
# 0                                   0.010873
# 1                                   0.044270
# 2                                 168.321262
# 3                                   0.013005
# 4                                   0.041163
#
#    surface_downwelling_photosynthetic_photon_flux_in_air                 time
# 0                                           0.000000      2018-04-18 22:05:00
# 1                                           0.000000      2018-04-18 22:10:00
# 2                                         434.102123      2018-04-18 22:15:00
# 3                                           0.000000      2018-04-18 23:20:00
# 4                                           0.000000      2018-04-18 23:25:00

# %%
weather_df_0.columns
# Out:
# Index(['source', 'wind_speed', 'source_file', 'eastward_wind',
#        'northward_wind', 'air_temperature', 'relative_humidity',
#        'precipitation_rate', 'surface_downwelling_shortwave_flux_in_air',
#        'surface_downwelling_photosynthetic_photon_flux_in_air', 'time'],
#       dtype='object')

# %%
weather_df_0.shape
# Out:
# (36485, 11)

# %% [markdown]
# ### I. Drop and reorder columns
# * will drop `surface_downwelling` columns for now until I get more feedback

# %%
new_col_order = ['time', 'air_temperature', 'relative_humidity', 'precipitation_rate', 'eastward_wind', 'northward_wind']

# %%
weather_df_1 = pd.DataFrame(data=weather_df_0, index=weather_df_0.index, columns=new_col_order)
# weather_df_1.head()
# Out:
#                   time  air_temperature  relative_humidity  \
# 0  2018-04-18 22:05:00       290.105233          14.690333
# 1  2018-04-18 22:10:00       289.968000          15.773800
# 2  2018-04-18 22:15:00       290.044447          18.701601
# 3  2018-04-18 23:20:00       289.220977          20.263907
# 4  2018-04-18 23:25:00       288.693800          21.982733
#
#    precipitation_rate  eastward_wind  northward_wind
# 0                 0.0       0.599756       -0.233053
# 1                 0.0       1.329997       -0.316545
# 2                 0.0      -0.409435        0.435499
# 3                 0.0       0.064580       -1.225979
# 4                 0.0       0.068203       -1.376049

# %%
# weather_df_1.tail()

# %% [markdown]
# ### II. Add `date` column with no time values

# %%
time_values = weather_df_1.time.values
just_dates = []

for t in time_values:
    
    just_date = t[:10]
    just_dates.append(just_date)

# print(weather_df_1.shape[0])
# print(len(time_values))
# print(len(just_dates))
# Out:
# 36485
# 36485
# 36485

# %%
weather_df_1['date'] = just_dates
weather_df_1.tail()
# Out:
#                       time  air_temperature  relative_humidity  \
# 36480  2018-08-02 17:10:00       303.294156          43.538212
# 36481  2018-08-02 17:10:00       303.294156          43.538212
# 36482  2018-08-02 17:10:00       303.294156          43.538212
# 36483  2018-08-02 17:10:00       303.294156          43.538212
# 36484  2018-08-02 17:10:00       303.294156          43.538212
#
#        precipitation_rate  eastward_wind  northward_wind        date
# 36480                 0.0      -0.838302       -1.795093  2018-08-02
# 36481                 0.0      -0.838302       -1.795093  2018-08-02
# 36482                 0.0      -0.838302       -1.795093  2018-08-02
# 36483                 0.0      -0.838302       -1.795093  2018-08-02
# 36484                 0.0      -0.838302       -1.795093  2018-08-02

# %% [markdown]
# ### III. Convert temperature to Celsius
# * can round to nearest int (or not round at all) as needed

# %%
weather_df_2 = weather_df_1.copy()

# %%
weather_df_2['air_temp_C'] = round((weather_df_2['air_temperature'] - 273.15), 2)
weather_df_2.head()
# Out:
#                   time  air_temperature  relative_humidity  \
# 0  2018-04-18 22:05:00       290.105233          14.690333
# 1  2018-04-18 22:10:00       289.968000          15.773800
# 2  2018-04-18 22:15:00       290.044447          18.701601
# 3  2018-04-18 23:20:00       289.220977          20.263907
# 4  2018-04-18 23:25:00       288.693800          21.982733
#
#    precipitation_rate  eastward_wind  northward_wind        date  air_temp_C
# 0                 0.0       0.599756       -0.233053  2018-04-18       16.96
# 1                 0.0       1.329997       -0.316545  2018-04-18       16.82
# 2                 0.0      -0.409435        0.435499  2018-04-18       16.89
# 3                 0.0       0.064580       -1.225979  2018-04-18       16.07
# 4                 0.0       0.068203       -1.376049  2018-04-18       15.54

# %% [markdown]
# ### IV. Add max, min, and mean values
# * Temperature: Drop Kelvin column
# * Relative humidity
# * Precipitation rate
# * Eastward wind
# * Northward wind

# %%
weather_df_3 = weather_df_2.drop(labels='air_temperature', axis=1)
# weather_df_3.tail()
# Out:
#                       time  relative_humidity  precipitation_rate  \
# 36480  2018-08-02 17:10:00          43.538212                 0.0
# 36481  2018-08-02 17:10:00          43.538212                 0.0
# 36482  2018-08-02 17:10:00          43.538212                 0.0
# 36483  2018-08-02 17:10:00          43.538212                 0.0
# 36484  2018-08-02 17:10:00          43.538212                 0.0
#
#        eastward_wind  northward_wind        date  air_temp_C
# 36480      -0.838302       -1.795093  2018-08-02       30.14
# 36481      -0.838302       -1.795093  2018-08-02       30.14
# 36482      -0.838302       -1.795093  2018-08-02       30.14
# 36483      -0.838302       -1.795093  2018-08-02       30.14
# 36484      -0.838302       -1.795093  2018-08-02       30.14

# %% [markdown]
# Air temperatures

# %%
min_temp = weather_df_3.groupby('date')['air_temp_C'].min()
max_temp = weather_df_3.groupby('date')['air_temp_C'].max()
mean_temp = weather_df_3.groupby('date')['air_temp_C'].mean()

# %% [markdown]
# Relative humidity

# %%
min_relative_humidity = weather_df_3.groupby('date')['relative_humidity'].min()
max_relative_humidity = weather_df_3.groupby('date')['relative_humidity'].max()
mean_relative_humidity = weather_df_3.groupby('date')['relative_humidity'].mean()

# %% [markdown]
# Precipitation rate

# %%
min_precip_rate = weather_df_3.groupby('date')['precipitation_rate'].min()
max_precip_rate = weather_df_3.groupby('date')['precipitation_rate'].max()
mean_precip_rate = weather_df_3.groupby('date')['precipitation_rate'].mean()

# %% [markdown]
# Northward wind

# %%
min_north_wind = weather_df_3.groupby('date')['northward_wind'].min()
max_north_wind = weather_df_3.groupby('date')['northward_wind'].max()
mean_north_wind = weather_df_3.groupby('date')['northward_wind'].mean()

# %% [markdown]
# Eastward wind

# %%
min_east_wind = weather_df_3.groupby('date')['eastward_wind'].min()
max_east_wind = weather_df_3.groupby('date')['eastward_wind'].max()
mean_east_wind = weather_df_3.groupby('date')['eastward_wind'].mean()

# %% [markdown]
# #### Create new dataframe with new values

# %%
daily_weather_values = pd.DataFrame({'min_temp': min_temp, 'max_temp': max_temp, 'mean_temp': mean_temp,
                                    'min_relative_humidity': min_relative_humidity, 'max_relative_humidity': max_relative_humidity,
                                    'mean_relative_humidity': mean_relative_humidity, 'min_precip_rate': min_precip_rate,
                                    'max_precip_rate': max_precip_rate, 'mean_precip_rate': mean_precip_rate})
daily_weather_values.head()
# Out:
#             min_temp  max_temp  mean_temp  min_relative_humidity  \
# date
# 2018-04-18     14.42     22.46  16.098333              11.702396
# 2018-04-19     14.94     20.35  17.011905              18.186243
# 2018-04-20     15.70     15.70  15.700000              30.504433
# 2018-04-22     18.59     31.52  26.610571              10.341967
# 2018-04-23     19.69     28.59  23.213171              11.042233
#
#             max_relative_humidity  mean_relative_humidity  min_precip_rate  \
# date
# 2018-04-18              23.698800               20.092809              0.0
# 2018-04-19              30.911200               25.800597              0.0
# 2018-04-20              30.504433               30.504433              0.0
# 2018-04-22              31.280344               14.259545              0.0
# 2018-04-23              29.809400               19.124050              0.0
#
#             max_precip_rate  mean_precip_rate
# date
# 2018-04-18              0.0               0.0
# 2018-04-19              0.0               0.0
# 2018-04-20              0.0               0.0
# 2018-04-22              0.0               0.0
# 2018-04-23              0.0               0.0

# %%
daily_weather_values_1 = daily_weather_values.sort_index()
daily_weather_values_1.tail()
# Out:
#             min_temp  max_temp  mean_temp  min_relative_humidity  \
# date
# 2018-07-29     25.97     36.38  30.973393              29.232762
# 2018-07-30     27.65     38.34  31.440476              30.470972
# 2018-07-31     28.46     41.56  35.763731              19.611500
# 2018-08-01     32.25     43.64  38.199437              16.258933
# 2018-08-02     30.14     43.43  38.838834              19.227533
#
#             max_relative_humidity  mean_relative_humidity  min_precip_rate  \
# date
# 2018-07-29              80.706667               51.977446              0.0
# 2018-07-30              59.852200               46.333852              0.0
# 2018-07-31              57.098533               33.659175              0.0
# 2018-08-01              48.735874               27.809735              0.0
# 2018-08-02              43.538212               26.787390              0.0
#
#             max_precip_rate  mean_precip_rate
# date
# 2018-07-29            0.254          0.004536
# 2018-07-30            0.000          0.000000
# 2018-07-31            0.000          0.000000
# 2018-08-01            0.000          0.000000
# 2018-08-02            0.000          0.000000

# %% [markdown]
# ### V. Add GDD

# %%
daily_weather_values_2 = daily_weather_values_1.copy()

# %%
daily_weather_values_2['gdd'] = np.rint(np.cumsum((((daily_weather_values_2['max_temp'] + daily_weather_values_2['min_temp']) / 2) - 10)))

# %% [markdown]
# Check that no daily gdd values were below 0

# %%
# there should be no output

for i,r in daily_weather_values_1.iterrows():
    
    if ((((r['min_temp'] + r['max_temp']) / 2)) - 10) < 0:
        print(i)
        print(r)

# %%
daily_weather_values_2.head()
# Out:
#             min_temp  max_temp  mean_temp  min_relative_humidity  \
# date
# 2018-04-18     14.42     22.46  16.098333              11.702396
# 2018-04-19     14.94     20.35  17.011905              18.186243
# 2018-04-20     15.70     15.70  15.700000              30.504433
# 2018-04-22     18.59     31.52  26.610571              10.341967
# 2018-04-23     19.69     28.59  23.213171              11.042233
#
#             max_relative_humidity  mean_relative_humidity  min_precip_rate  \
# date
# 2018-04-18              23.698800               20.092809              0.0
# 2018-04-19              30.911200               25.800597              0.0
# 2018-04-20              30.504433               30.504433              0.0
# 2018-04-22              31.280344               14.259545              0.0
# 2018-04-23              29.809400               19.124050              0.0
#
#             max_precip_rate  mean_precip_rate   gdd
# date
# 2018-04-18              0.0               0.0   8.0
# 2018-04-19              0.0               0.0  16.0
# 2018-04-20              0.0               0.0  22.0
# 2018-04-22              0.0               0.0  37.0
# 2018-04-23              0.0               0.0  51.0

# %% [markdown]
# ### Final Steps

# %%
need_to_create_csv = True

if need_to_create_csv:

    timestamp = datetime.datetime.now().replace(microsecond=0).isoformat()
    output_filename = f'daily_weather_values_season_6_{timestamp}.csv'.replace(':', '')
    daily_weather_values_2.to_csv(f'data/processed/{output_filename}')
