# %% [markdown]
# ## Weather Station Data Season 4
#
# ### MAC Weather Station
# * 2017 raw [data](https://cals.arizona.edu/azmet/06.htm)

# %%
import datetime
import numpy as np
import pandas as pd

# %%
df_0 = pd.read_csv('data/raw/mac_weather_station_raw_daily_2017.csv')
# df_0.head()
# Out:
#    year  day_of_year  station_number  air_temp_max  air_temp_min  \
# 0  2017            1               6          13.6           9.3
# 1  2017            2               6          14.9           7.2
# 2  2017            3               6          13.9           3.2
# 3  2017            4               6          20.4           3.0
# 4  2017            5               6          20.9           4.0
#
#    air_temp_mean  rh_max  rh_min  rh_mean  vpd_mean  ...  wind_speed_mean  \
# 0           11.8    92.7    69.2     83.5      0.23  ...              3.5
# 1           10.5    87.7    44.7     71.4      0.39  ...              2.2
# 2            9.0    97.0    60.6     81.9      0.24  ...              1.0
# 3           11.0    97.8    31.4     73.2      0.46  ...              0.9
# 4           12.3    95.5    39.8     71.0      0.53  ...              1.5
#
#    wind_vector_magnitude  wind_vector_direction  wind_direction_std  \
# 0                    2.6                    188                  43
# 1                    1.5                    129                  44
# 2                    0.1                    349                  78
# 3                    0.3                     76                  68
# 4                    0.8                    253                  54
#
#    max_wind_speed  heat_units  eto_azmet  eto_p_m  vapor_pressure_mean  \
# 0            10.9         0.2        1.0      1.2                 1.16
# 1             5.8         0.5        1.0      1.6                 0.89
# 2             3.3         0.2        0.6      0.9                 0.93
# 3             3.6         2.3        1.8      1.5                 0.92
# 4             7.1         2.5        2.2      1.8                 0.98
#
#    dewpoint_mean
# 0            9.0
# 1            5.3
# 2            5.8
# 3            5.7
# 4            6.6
#
# [5 rows x 28 columns]

# %%
df_0.shape
# Out:
# (365, 28)

# %% [markdown]
# ### I. Drop columns not needed at this time

# %%
df_0.columns
# Out:
# Index(['year', 'day_of_year', 'station_number', 'air_temp_max', 'air_temp_min',
#        'air_temp_mean', 'rh_max', 'rh_min', 'rh_mean', 'vpd_mean',
#        'solar_rad_total', 'precip_total', '4_in_soil_temp_max',
#        '4_in_soil_temp_min', '4_in_soil_temp_mean', '20_in_soil_temp_max',
#        '20_in_soil_temp_min', '20_in_soil_temp_mean', 'wind_speed_mean',
#        'wind_vector_magnitude', 'wind_vector_direction', 'wind_direction_std',
#        'max_wind_speed', 'heat_units', 'eto_azmet', 'eto_p_m',
#        'vapor_pressure_mean', 'dewpoint_mean'],
#       dtype='object')

# %%
cols_to_drop = ['year', 'station_number', 'vpd_mean', 'solar_rad_total', '4_in_soil_temp_max', '4_in_soil_temp_min',
                '4_in_soil_temp_mean', '20_in_soil_temp_max', '20_in_soil_temp_min', '20_in_soil_temp_mean',
                'heat_units', 'eto_azmet', 'eto_p_m', 'vapor_pressure_mean', 'dewpoint_mean']

# %%
df_1 = df_0.drop(labels=cols_to_drop, axis=1)
df_1.head()
# Out:
#    day_of_year  air_temp_max  air_temp_min  air_temp_mean  rh_max  rh_min  \
# 0            1          13.6           9.3           11.8    92.7    69.2
# 1            2          14.9           7.2           10.5    87.7    44.7
# 2            3          13.9           3.2            9.0    97.0    60.6
# 3            4          20.4           3.0           11.0    97.8    31.4
# 4            5          20.9           4.0           12.3    95.5    39.8
#
#    rh_mean  precip_total  wind_speed_mean  wind_vector_magnitude  \
# 0     83.5          1.78              3.5                    2.6
# 1     71.4          0.00              2.2                    1.5
# 2     81.9          0.00              1.0                    0.1
# 3     73.2          0.00              0.9                    0.3
# 4     71.0          0.00              1.5                    0.8
#
#    wind_vector_direction  wind_direction_std  max_wind_speed
# 0                    188                  43            10.9
# 1                    129                  44             5.8
# 2                    349                  78             3.3
# 3                     76                  68             3.6
# 4                    253                  54             7.1

# %% [markdown]
# ### II. Slice dataframe for season dates only and add date column
# * Planting Date: 2017-04-20, Day 110
# * Last Day of Harvest: 2017-09-16, Day 259

# %%
df_2 = df_1.loc[(df_1.day_of_year >= 110) & (df_1.day_of_year <= 259)]
df_2.shape
# Out:
# (150, 13)

# %%
season_4_date_range = pd.date_range(start='2017-04-20', end='2017-09-16')

# %%
df_3 = df_2.copy()
df_3['date'] = season_4_date_range
# df_3.head()
# Out:
#      day_of_year  air_temp_max  air_temp_min  air_temp_mean  rh_max  rh_min  \
# 109          110          33.3          14.1           23.5    45.0     5.1
# 110          111          34.4          11.1           24.0    46.5     5.5
# 111          112          35.5          14.5           25.0    32.5     6.4
# 112          113          37.0          12.6           26.5    48.0     6.8
# 113          114          33.7          14.9           25.7    33.1     8.3
#
#      rh_mean  precip_total  wind_speed_mean  wind_vector_magnitude  \
# 109     18.2           0.0              1.9                    0.8
# 110     17.2           0.0              2.2                    1.3
# 111     15.6           0.0              1.6                    0.5
# 112     17.5           0.0              2.1                    1.1
# 113     17.5           0.0              3.0                    2.0
#
#      wind_vector_direction  wind_direction_std  max_wind_speed       date
# 109                    233                  60             8.2 2017-04-20
# 110                    274                  52             8.5 2017-04-21
# 111                    178                  66             5.2 2017-04-22
# 112                    221                  57             8.2 2017-04-23
# 113                    214                  46             9.9 2017-04-24

# %% [markdown]
# ### III. Add Growing Degree Days (gdd)

# %%
df_4 = df_3.copy()
df_4['gdd'] = np.rint(np.cumsum((((df_4['air_temp_max'] + df_4['air_temp_min']) / 2) - 10)))
# df_4.head()
# Out:
#      day_of_year  air_temp_max  air_temp_min  air_temp_mean  rh_max  rh_min  \
# 109          110          33.3          14.1           23.5    45.0     5.1
# 110          111          34.4          11.1           24.0    46.5     5.5
# 111          112          35.5          14.5           25.0    32.5     6.4
# 112          113          37.0          12.6           26.5    48.0     6.8
# 113          114          33.7          14.9           25.7    33.1     8.3
#
#      rh_mean  precip_total  wind_speed_mean  wind_vector_magnitude  \
# 109     18.2           0.0              1.9                    0.8
# 110     17.2           0.0              2.2                    1.3
# 111     15.6           0.0              1.6                    0.5
# 112     17.5           0.0              2.1                    1.1
# 113     17.5           0.0              3.0                    2.0
#
#      wind_vector_direction  wind_direction_std  max_wind_speed       date  \
# 109                    233                  60             8.2 2017-04-20
# 110                    274                  52             8.5 2017-04-21
# 111                    178                  66             5.2 2017-04-22
# 112                    221                  57             8.2 2017-04-23
# 113                    214                  46             9.9 2017-04-24
#
#       gdd
# 109  14.0
# 110  26.0
# 111  41.0
# 112  56.0
# 113  71.0

# %% [markdown]
# ### IV. Add cumulative precipitation

# %%
df_5 = df_4.copy()
df_5['cum_precip'] = round(np.cumsum(df_5.precip_total), 2)
# df_5.tail()
# Out:
#      day_of_year  air_temp_max  air_temp_min  air_temp_mean  rh_max  rh_min  \
# 254          255          42.8          24.2           34.0    58.0    13.3
# 255          256          41.3          24.3           33.9    54.1    14.3
# 256          257          39.5          22.8           31.4    50.6    17.8
# 257          258          36.2          21.4           28.5    63.7    14.2
# 258          259          36.3          18.2           27.6    51.4    16.7
#
#      rh_mean  precip_total  wind_speed_mean  wind_vector_magnitude  \
# 254     28.1           0.0              1.6                    0.4
# 255     27.3           0.0              2.2                    1.4
# 256     32.9           0.0              4.3                    3.6
# 257     33.7           0.0              2.9                    2.1
# 258     29.9           0.0              2.2                    1.4
#
#      wind_vector_direction  wind_direction_std  max_wind_speed       date  \
# 254                    263                  70             6.2 2017-09-12
# 255                    244                  49            11.6 2017-09-13
# 256                    203                  34            13.6 2017-09-14
# 257                    192                  42             9.9 2017-09-15
# 258                    168                  47             8.0 2017-09-16
#
#         gdd  cum_precip
# 254  2955.0       50.79
# 255  2978.0       50.79
# 256  2999.0       50.79
# 257  3018.0       50.79
# 258  3035.0       50.79

# %% [markdown]
# ### V. Set date as index

# %%
df_6 = df_5.set_index(keys='date')
# df_6.head()
# Out:
#             day_of_year  air_temp_max  air_temp_min  air_temp_mean  rh_max  \
# date
# 2017-04-20          110          33.3          14.1           23.5    45.0
# 2017-04-21          111          34.4          11.1           24.0    46.5
# 2017-04-22          112          35.5          14.5           25.0    32.5
# 2017-04-23          113          37.0          12.6           26.5    48.0
# 2017-04-24          114          33.7          14.9           25.7    33.1
#
#             rh_min  rh_mean  precip_total  wind_speed_mean  \
# date
# 2017-04-20     5.1     18.2           0.0              1.9
# 2017-04-21     5.5     17.2           0.0              2.2
# 2017-04-22     6.4     15.6           0.0              1.6
# 2017-04-23     6.8     17.5           0.0              2.1
# 2017-04-24     8.3     17.5           0.0              3.0
#
#             wind_vector_magnitude  wind_vector_direction  wind_direction_std  \
# date
# 2017-04-20                    0.8                    233                  60
# 2017-04-21                    1.3                    274                  52
# 2017-04-22                    0.5                    178                  66
# 2017-04-23                    1.1                    221                  57
# 2017-04-24                    2.0                    214                  46
#
#             max_wind_speed   gdd  cum_precip
# date
# 2017-04-20             8.2  14.0         0.0
# 2017-04-21             8.5  26.0         0.0
# 2017-04-22             5.2  41.0         0.0
# 2017-04-23             8.2  56.0         0.0
# 2017-04-24             9.9  71.0         0.0

# %% [markdown]
# ### Convert to `.csv`

# %%
need_to_create_csv = True

if need_to_create_csv:

    timestamp = datetime.datetime.now().replace(microsecond=0).isoformat()
    output_filename = f'weather_station_season_4_{timestamp}.csv'.replace(':', '')
    df_6.to_csv(f'data/processed/{output_filename}')
